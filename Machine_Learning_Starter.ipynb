# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
planets_df = pd.read_csv("Cleaned_Planet_Exploration_Data.csv")
planets_df.head()
# Out:
#     KOI_Name Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# 0  K00752.01                     CONFIRMED               9.488036
# 1  K00752.02                     CONFIRMED              54.418383
# 2  K00753.01                     CANDIDATE              19.899140
# 3  K00754.01                FALSE POSITIVE               1.736952
# 4  K00755.01                     CONFIRMED               2.525592
#
#    Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# 0                      2.775000e-05                     -2.775000e-05
# 1                      2.479000e-04                     -2.479000e-04
# 2                      1.494000e-05                     -1.494000e-05
# 3                      2.630000e-07                     -2.630000e-07
# 4                      3.761000e-06                     -3.761000e-06
#
#    Transit_Epoch_[BKJD]  Transit_Epoch_Upper_Unc._[BKJD]  \
# 0            170.538750                         0.002160
# 1            162.513840                         0.003520
# 2            175.850252                         0.000581
# 3            170.307565                         0.000115
# 4            171.595550                         0.001130
#
#    Transit_Epoch_Lower_Unc._[BKJD]  Impact_Parameter  \
# 0                        -0.002160             0.146
# 1                        -0.003520             0.586
# 2                        -0.000581             0.969
# 3                        -0.000115             1.276
# 4                        -0.001130             0.701
#
#    Impact_Parameter_Upper_Unc.  ...  \
# 0                        0.318  ...
# 1                        0.059  ...
# 2                        5.126  ...
# 3                        0.115  ...
# 4                        0.235  ...
#
#    Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                         -81.0
# 1                                         -81.0
# 2                                        -176.0
# 3                                        -174.0
# 4                                        -211.0
#
#    Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                     4.467
# 1                                     4.467
# 2                                     4.544
# 3                                     4.564
# 4                                     4.438
#
#    Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                              0.064
# 1                                              0.064
# 2                                              0.044
# 3                                              0.053
# 4                                              0.070
#
#    Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                             -0.096
# 1                                             -0.096
# 2                                             -0.176
# 3                                             -0.168
# 4                                             -0.210
#
#    Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                         0.927                                    0.105
# 1                         0.927                                    0.105
# 2                         0.868                                    0.233
# 3                         0.791                                    0.201
# 4                         1.046                                    0.334
#
#    Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                   -0.061             291.93423
# 1                                   -0.061             291.93423
# 2                                   -0.078             297.00482
# 3                                   -0.067             285.53461
# 4                                   -0.133             288.75488
#
#    Dec_[decimal_degrees]  Kepler-band_[mag]
# 0              48.141651             15.347
# 1              48.141651             15.347
# 2              48.134129             15.436
# 3              48.285210             15.597
# 4              48.226200             15.509
#
# [5 rows x 39 columns]

# %%
planets_df = planets_df.drop(columns = ["TCE_Delivery", "TCE_Planet_Number"])
planets_df
# Out:
#        KOI_Name Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# 0     K00752.01                     CONFIRMED               9.488036
# 1     K00752.02                     CONFIRMED              54.418383
# 2     K00753.01                     CANDIDATE              19.899140
# 3     K00754.01                FALSE POSITIVE               1.736952
# 4     K00755.01                     CONFIRMED               2.525592
# ...         ...                           ...                    ...
# 9559  K07985.01                FALSE POSITIVE               0.527699
# 9560  K07986.01                     CANDIDATE               1.739849
# 9561  K07987.01                FALSE POSITIVE               0.681402
# 9562  K07988.01                     CANDIDATE             333.486169
# 9563  K07989.01                FALSE POSITIVE               4.856035
#
#       Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# 0                         2.775000e-05                     -2.775000e-05
# 1                         2.479000e-04                     -2.479000e-04
# 2                         1.494000e-05                     -1.494000e-05
# 3                         2.630000e-07                     -2.630000e-07
# 4                         3.761000e-06                     -3.761000e-06
# ...                                ...                               ...
# 9559                      1.160000e-07                     -1.160000e-07
# 9560                      1.780000e-05                     -1.780000e-05
# 9561                      2.434000e-06                     -2.434000e-06
# 9562                      4.235000e-03                     -4.235000e-03
# 9563                      6.356000e-05                     -6.356000e-05
#
#       Transit_Epoch_[BKJD]  Transit_Epoch_Upper_Unc._[BKJD]  \
# 0               170.538750                         0.002160
# 1               162.513840                         0.003520
# 2               175.850252                         0.000581
# 3               170.307565                         0.000115
# 4               171.595550                         0.001130
# ...                    ...                              ...
# 9559            131.705093                         0.000170
# 9560            133.001270                         0.007690
# 9561            132.181750                         0.002850
# 9562            153.615010                         0.005070
# 9563            135.993300                         0.010800
#
#       Transit_Epoch_Lower_Unc._[BKJD]  Impact_Parameter  \
# 0                           -0.002160             0.146
# 1                           -0.003520             0.586
# 2                           -0.000581             0.969
# 3                           -0.000115             1.276
# 4                           -0.001130             0.701
# ...                               ...               ...
# 9559                        -0.000170             1.252
# 9560                        -0.007690             0.043
# 9561                        -0.002850             0.147
# 9562                        -0.005070             0.214
# 9563                        -0.010800             0.134
#
#       Impact_Parameter_Upper_Unc.  ...  \
# 0                           0.318  ...
# 1                           0.059  ...
# 2                           5.126  ...
# 3                           0.115  ...
# 4                           0.235  ...
# ...                           ...  ...
# 9559                        0.051  ...
# 9560                        0.423  ...
# 9561                        0.309  ...
# 9562                        0.255  ...
# 9563                        0.323  ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 2                                           -176.0
# 3                                           -174.0
# 4                                           -211.0
# ...                                            ...
# 9559                                        -166.0
# 9560                                        -220.0
# 9561                                        -236.0
# 9562                                        -128.0
# 9563                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 37 columns]

# %%
planets_df=planets_df.set_index('KOI_Name')
planets_df
# Out:
#           Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# KOI_Name
# K00752.01                     CONFIRMED               9.488036
# K00752.02                     CONFIRMED              54.418383
# K00753.01                     CANDIDATE              19.899140
# K00754.01                FALSE POSITIVE               1.736952
# K00755.01                     CONFIRMED               2.525592
# ...                                 ...                    ...
# K07985.01                FALSE POSITIVE               0.527699
# K07986.01                     CANDIDATE               1.739849
# K07987.01                FALSE POSITIVE               0.681402
# K07988.01                     CANDIDATE             333.486169
# K07989.01                FALSE POSITIVE               4.856035
#
#            Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# KOI_Name
# K00752.01                      2.775000e-05                     -2.775000e-05
# K00752.02                      2.479000e-04                     -2.479000e-04
# K00753.01                      1.494000e-05                     -1.494000e-05
# K00754.01                      2.630000e-07                     -2.630000e-07
# K00755.01                      3.761000e-06                     -3.761000e-06
# ...                                     ...                               ...
# K07985.01                      1.160000e-07                     -1.160000e-07
# K07986.01                      1.780000e-05                     -1.780000e-05
# K07987.01                      2.434000e-06                     -2.434000e-06
# K07988.01                      4.235000e-03                     -4.235000e-03
# K07989.01                      6.356000e-05                     -6.356000e-05
#
#            Transit_Epoch_[BKJD]  Transit_Epoch_Upper_Unc._[BKJD]  \
# KOI_Name
# K00752.01            170.538750                         0.002160
# K00752.02            162.513840                         0.003520
# K00753.01            175.850252                         0.000581
# K00754.01            170.307565                         0.000115
# K00755.01            171.595550                         0.001130
# ...                         ...                              ...
# K07985.01            131.705093                         0.000170
# K07986.01            133.001270                         0.007690
# K07987.01            132.181750                         0.002850
# K07988.01            153.615010                         0.005070
# K07989.01            135.993300                         0.010800
#
#            Transit_Epoch_Lower_Unc._[BKJD]  Impact_Parameter  \
# KOI_Name
# K00752.01                        -0.002160             0.146
# K00752.02                        -0.003520             0.586
# K00753.01                        -0.000581             0.969
# K00754.01                        -0.000115             1.276
# K00755.01                        -0.001130             0.701
# ...                                    ...               ...
# K07985.01                        -0.000170             1.252
# K07986.01                        -0.007690             0.043
# K07987.01                        -0.002850             0.147
# K07988.01                        -0.005070             0.214
# K07989.01                        -0.010800             0.134
#
#            Impact_Parameter_Upper_Unc.  Impact_Parameter_Lower_Unc.  ...  \
# KOI_Name                                                             ...
# K00752.01                        0.318                       -0.146  ...
# K00752.02                        0.059                       -0.443  ...
# K00753.01                        5.126                       -0.077  ...
# K00754.01                        0.115                       -0.092  ...
# K00755.01                        0.235                       -0.478  ...
# ...                                ...                          ...  ...
# K07985.01                        0.051                       -0.049  ...
# K07986.01                        0.423                       -0.043  ...
# K07987.01                        0.309                       -0.147  ...
# K07988.01                        0.255                       -0.214  ...
# K07989.01                        0.323                       -0.134  ...
#
#            Stellar_Effective_Temperature_Lower_Unc._[K]  \
# KOI_Name
# K00752.01                                         -81.0
# K00752.02                                         -81.0
# K00753.01                                        -176.0
# K00754.01                                        -174.0
# K00755.01                                        -211.0
# ...                                                 ...
# K07985.01                                        -166.0
# K07986.01                                        -220.0
# K07987.01                                        -236.0
# K07988.01                                        -128.0
# K07989.01                                        -225.0
#
#            Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                     4.467
# K00752.02                                     4.467
# K00753.01                                     4.544
# K00754.01                                     4.564
# K00755.01                                     4.438
# ...                                             ...
# K07985.01                                     4.529
# K07986.01                                     4.444
# K07987.01                                     4.447
# K07988.01                                     2.992
# K07989.01                                     4.385
#
#            Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                              0.064
# K00752.02                                              0.064
# K00753.01                                              0.044
# K00754.01                                              0.053
# K00755.01                                              0.070
# ...                                                      ...
# K07985.01                                              0.035
# K07986.01                                              0.056
# K07987.01                                              0.056
# K07988.01                                              0.030
# K07989.01                                              0.054
#
#            Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                             -0.096
# K00752.02                                             -0.096
# K00753.01                                             -0.176
# K00754.01                                             -0.168
# K00755.01                                             -0.210
# ...                                                      ...
# K07985.01                                             -0.196
# K07986.01                                             -0.224
# K07987.01                                             -0.224
# K07988.01                                             -0.027
# K07989.01                                             -0.216
#
#            Stellar_Radius_[Solar_radii]  \
# KOI_Name
# K00752.01                         0.927
# K00752.02                         0.927
# K00753.01                         0.868
# K00754.01                         0.791
# K00755.01                         1.046
# ...                                 ...
# K07985.01                         0.903
# K07986.01                         1.031
# K07987.01                         1.041
# K07988.01                         7.824
# K07989.01                         1.193
#
#            Stellar_Radius_Upper_Unc._[Solar_radii]  \
# KOI_Name
# K00752.01                                    0.105
# K00752.02                                    0.105
# K00753.01                                    0.233
# K00754.01                                    0.201
# K00755.01                                    0.334
# ...                                            ...
# K07985.01                                    0.237
# K07986.01                                    0.341
# K07987.01                                    0.341
# K07988.01                                    0.223
# K07989.01                                    0.410
#
#            Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# KOI_Name
# K00752.01                                   -0.061             291.93423
# K00752.02                                   -0.061             291.93423
# K00753.01                                   -0.078             297.00482
# K00754.01                                   -0.067             285.53461
# K00755.01                                   -0.133             288.75488
# ...                                            ...                   ...
# K07985.01                                   -0.079             297.18875
# K07986.01                                   -0.114             286.50937
# K07987.01                                   -0.114             294.16489
# K07988.01                                   -1.896             296.76288
# K07989.01                                   -0.137             297.00977
#
#            Dec_[decimal_degrees]  Kepler-band_[mag]
# KOI_Name
# K00752.01              48.141651             15.347
# K00752.02              48.141651             15.347
# K00753.01              48.134129             15.436
# K00754.01              48.285210             15.597
# K00755.01              48.226200             15.509
# ...                          ...                ...
# K07985.01              47.093819             14.082
# K07986.01              47.163219             14.757
# K07987.01              47.176281             15.385
# K07988.01              47.145142             10.998
# K07989.01              47.121021             14.826
#
# [9564 rows x 36 columns]

# %%
planets_category = planets_df.dtypes[planets_df.dtypes == "object"].index.tolist()
planets_category
# Out:
# ['Exoplanet_Archive_Disposition']

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(planets_df[planets_category]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(planets_category)
encode_df.index = planets_df.index
encode_df
# Out:
#            Exoplanet_Archive_Disposition_CANDIDATE  \
# KOI_Name
# K00752.01                                      0.0
# K00752.02                                      0.0
# K00753.01                                      1.0
# K00754.01                                      0.0
# K00755.01                                      0.0
# ...                                            ...
# K07985.01                                      0.0
# K07986.01                                      1.0
# K07987.01                                      0.0
# K07988.01                                      1.0
# K07989.01                                      0.0
#
#            Exoplanet_Archive_Disposition_CONFIRMED  \
# KOI_Name
# K00752.01                                      1.0
# K00752.02                                      1.0
# K00753.01                                      0.0
# K00754.01                                      0.0
# K00755.01                                      1.0
# ...                                            ...
# K07985.01                                      0.0
# K07986.01                                      0.0
# K07987.01                                      0.0
# K07988.01                                      0.0
# K07989.01                                      0.0
#
#            Exoplanet_Archive_Disposition_FALSE POSITIVE
# KOI_Name
# K00752.01                                           0.0
# K00752.02                                           0.0
# K00753.01                                           0.0
# K00754.01                                           1.0
# K00755.01                                           0.0
# ...                                                 ...
# K07985.01                                           1.0
# K07986.01                                           0.0
# K07987.01                                           1.0
# K07988.01                                           0.0
# K07989.01                                           1.0
#
# [9564 rows x 3 columns]

# %%
# Merge one-hot encoded features and drop the originals
new_planets_df = planets_df.merge(encode_df, left_index=True,right_index=True).drop(columns = planets_category)
new_planets_df
# Out:
#            Orbital_Period_[days]  Orbital_Period_Upper_Unc._[days]  \
# KOI_Name
# K00752.01               9.488036                      2.775000e-05
# K00752.02              54.418383                      2.479000e-04
# K00753.01              19.899140                      1.494000e-05
# K00754.01               1.736952                      2.630000e-07
# K00755.01               2.525592                      3.761000e-06
# ...                          ...                               ...
# K07985.01               0.527699                      1.160000e-07
# K07986.01               1.739849                      1.780000e-05
# K07987.01               0.681402                      2.434000e-06
# K07988.01             333.486169                      4.235000e-03
# K07989.01               4.856035                      6.356000e-05
#
#            Orbital_Period_Lower_Unc._[days]  Transit_Epoch_[BKJD]  \
# KOI_Name
# K00752.01                     -2.775000e-05            170.538750
# K00752.02                     -2.479000e-04            162.513840
# K00753.01                     -1.494000e-05            175.850252
# K00754.01                     -2.630000e-07            170.307565
# K00755.01                     -3.761000e-06            171.595550
# ...                                     ...                   ...
# K07985.01                     -1.160000e-07            131.705093
# K07986.01                     -1.780000e-05            133.001270
# K07987.01                     -2.434000e-06            132.181750
# K07988.01                     -4.235000e-03            153.615010
# K07989.01                     -6.356000e-05            135.993300
#
#            Transit_Epoch_Upper_Unc._[BKJD]  Transit_Epoch_Lower_Unc._[BKJD]  \
# KOI_Name
# K00752.01                         0.002160                        -0.002160
# K00752.02                         0.003520                        -0.003520
# K00753.01                         0.000581                        -0.000581
# K00754.01                         0.000115                        -0.000115
# K00755.01                         0.001130                        -0.001130
# ...                                    ...                              ...
# K07985.01                         0.000170                        -0.000170
# K07986.01                         0.007690                        -0.007690
# K07987.01                         0.002850                        -0.002850
# K07988.01                         0.005070                        -0.005070
# K07989.01                         0.010800                        -0.010800
#
#            Impact_Parameter  Impact_Parameter_Upper_Unc.  \
# KOI_Name
# K00752.01             0.146                        0.318
# K00752.02             0.586                        0.059
# K00753.01             0.969                        5.126
# K00754.01             1.276                        0.115
# K00755.01             0.701                        0.235
# ...                     ...                          ...
# K07985.01             1.252                        0.051
# K07986.01             0.043                        0.423
# K07987.01             0.147                        0.309
# K07988.01             0.214                        0.255
# K07989.01             0.134                        0.323
#
#            Impact_Parameter_Lower_Unc.  Transit_Duration_[hrs]  ...  \
# KOI_Name                                                        ...
# K00752.01                       -0.146                 2.95750  ...
# K00752.02                       -0.443                 4.50700  ...
# K00753.01                       -0.077                 1.78220  ...
# K00754.01                       -0.092                 2.40641  ...
# K00755.01                       -0.478                 1.65450  ...
# ...                                ...                     ...  ...
# K07985.01                       -0.049                 3.22210  ...
# K07986.01                       -0.043                 3.11400  ...
# K07987.01                       -0.147                 0.86500  ...
# K07988.01                       -0.214                 3.19900  ...
# K07989.01                       -0.134                 3.07800  ...
#
#            Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                             -0.096
# K00752.02                                             -0.096
# K00753.01                                             -0.176
# K00754.01                                             -0.168
# K00755.01                                             -0.210
# ...                                                      ...
# K07985.01                                             -0.196
# K07986.01                                             -0.224
# K07987.01                                             -0.224
# K07988.01                                             -0.027
# K07989.01                                             -0.216
#
#            Stellar_Radius_[Solar_radii]  \
# KOI_Name
# K00752.01                         0.927
# K00752.02                         0.927
# K00753.01                         0.868
# K00754.01                         0.791
# K00755.01                         1.046
# ...                                 ...
# K07985.01                         0.903
# K07986.01                         1.031
# K07987.01                         1.041
# K07988.01                         7.824
# K07989.01                         1.193
#
#            Stellar_Radius_Upper_Unc._[Solar_radii]  \
# KOI_Name
# K00752.01                                    0.105
# K00752.02                                    0.105
# K00753.01                                    0.233
# K00754.01                                    0.201
# K00755.01                                    0.334
# ...                                            ...
# K07985.01                                    0.237
# K07986.01                                    0.341
# K07987.01                                    0.341
# K07988.01                                    0.223
# K07989.01                                    0.410
#
#            Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# KOI_Name
# K00752.01                                   -0.061             291.93423
# K00752.02                                   -0.061             291.93423
# K00753.01                                   -0.078             297.00482
# K00754.01                                   -0.067             285.53461
# K00755.01                                   -0.133             288.75488
# ...                                            ...                   ...
# K07985.01                                   -0.079             297.18875
# K07986.01                                   -0.114             286.50937
# K07987.01                                   -0.114             294.16489
# K07988.01                                   -1.896             296.76288
# K07989.01                                   -0.137             297.00977
#
#            Dec_[decimal_degrees]  Kepler-band_[mag]  \
# KOI_Name
# K00752.01              48.141651             15.347
# K00752.02              48.141651             15.347
# K00753.01              48.134129             15.436
# K00754.01              48.285210             15.597
# K00755.01              48.226200             15.509
# ...                          ...                ...
# K07985.01              47.093819             14.082
# K07986.01              47.163219             14.757
# K07987.01              47.176281             15.385
# K07988.01              47.145142             10.998
# K07989.01              47.121021             14.826
#
#            Exoplanet_Archive_Disposition_CANDIDATE  \
# KOI_Name
# K00752.01                                      0.0
# K00752.02                                      0.0
# K00753.01                                      1.0
# K00754.01                                      0.0
# K00755.01                                      0.0
# ...                                            ...
# K07985.01                                      0.0
# K07986.01                                      1.0
# K07987.01                                      0.0
# K07988.01                                      1.0
# K07989.01                                      0.0
#
#            Exoplanet_Archive_Disposition_CONFIRMED  \
# KOI_Name
# K00752.01                                      1.0
# K00752.02                                      1.0
# K00753.01                                      0.0
# K00754.01                                      0.0
# K00755.01                                      1.0
# ...                                            ...
# K07985.01                                      0.0
# K07986.01                                      0.0
# K07987.01                                      0.0
# K07988.01                                      0.0
# K07989.01                                      0.0
#
#            Exoplanet_Archive_Disposition_FALSE POSITIVE
# KOI_Name
# K00752.01                                           0.0
# K00752.02                                           0.0
# K00753.01                                           0.0
# K00754.01                                           1.0
# K00755.01                                           0.0
# ...                                                 ...
# K07985.01                                           1.0
# K07986.01                                           0.0
# K07987.01                                           1.0
# K07988.01                                           0.0
# K07989.01                                           1.0
#
# [9564 rows x 38 columns]

# %%
# Determine the number of unique values in each column.
new_planets_df.nunique()
# Out:
# Orbital_Period_[days]                                  9564
# Orbital_Period_Upper_Unc._[days]                       7448
# Orbital_Period_Lower_Unc._[days]                       7448
# Transit_Epoch_[BKJD]                                   9538
# Transit_Epoch_Upper_Unc._[BKJD]                        2530
# Transit_Epoch_Lower_Unc._[BKJD]                        2530
# Impact_Parameter                                       2406
# Impact_Parameter_Upper_Unc.                            2217
# Impact_Parameter_Lower_Unc.                            1884
# Transit_Duration_[hrs]                                 7834
# Transit_Duration_Upper_Unc._[hrs]                      2264
# Transit_Duration_Lower_Unc._[hrs]                      2264
# Transit_Depth_[ppm]                                    6947
# Transit_Depth_Upper_Unc._[ppm]                         1428
# Transit_Depth_Lower_Unc._[ppm]                         1428
# Planetary_Radius_[Earth_radii]                         2988
# Planetary_Radius_Upper_Unc._[Earth_radii]              1787
# Planetary_Radius_Lower_Unc._[Earth_radii]              1561
# Equilibrium_Temperature_[K]                            2511
# Insolation_Flux_[Earth_flux]                           7801
# Insolation_Flux_Upper_Unc._[Earth_flux]                7130
# Insolation_Flux_Lower_Unc._[Earth_flux]                6560
# Transit_Signal-to-Noise                                2740
# Stellar_Effective_Temperature_[K]                      2445
# Stellar_Effective_Temperature_Upper_Unc._[K]            265
# Stellar_Effective_Temperature_Lower_Unc._[K]            376
# Stellar_Surface_Gravity_[log10(cm/s**2)]               1557
# Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]     553
# Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]     430
# Stellar_Radius_[Solar_radii]                           2289
# Stellar_Radius_Upper_Unc._[Solar_radii]                1162
# Stellar_Radius_Lower_Unc._[Solar_radii]                1384
# RA_[decimal_degrees]                                   8131
# Dec_[decimal_degrees]                                  8195
# Kepler-band_[mag]                                      3887
# Exoplanet_Archive_Disposition_CANDIDATE                   2
# Exoplanet_Archive_Disposition_CONFIRMED                   2
# Exoplanet_Archive_Disposition_FALSE POSITIVE              2
# dtype: int64

# %%
#planets_value_counts = planets_df["TCE_Planet_Number"].value_counts()
#planets_value_counts

# %%
#planets_value_counts = planets_df["TCE_Delivery"].value_counts()
#planets_value_counts

# %%
planets_value_counts = planets_df["Stellar_Effective_Temperature_Upper_Unc._[K]"].value_counts()
planets_value_counts
# Out:
# 169.0    250
# 159.0    172
# 166.0    167
# 158.0    167
# 78.0     157
#         ...
# 331.0      1
# 433.0      1
# 45.0       1
# 402.0      1
# 330.0      1
# Name: Stellar_Effective_Temperature_Upper_Unc._[K], Length: 265, dtype: int64

# %%
new_planets_df = new_planets_df.drop(columns = ["Exoplanet_Archive_Disposition_CANDIDATE" , "Exoplanet_Archive_Disposition_FALSE POSITIVE"])
new_planets_df
# Out:
#            Orbital_Period_[days]  Orbital_Period_Upper_Unc._[days]  \
# KOI_Name
# K00752.01               9.488036                      2.775000e-05
# K00752.02              54.418383                      2.479000e-04
# K00753.01              19.899140                      1.494000e-05
# K00754.01               1.736952                      2.630000e-07
# K00755.01               2.525592                      3.761000e-06
# ...                          ...                               ...
# K07985.01               0.527699                      1.160000e-07
# K07986.01               1.739849                      1.780000e-05
# K07987.01               0.681402                      2.434000e-06
# K07988.01             333.486169                      4.235000e-03
# K07989.01               4.856035                      6.356000e-05
#
#            Orbital_Period_Lower_Unc._[days]  Transit_Epoch_[BKJD]  \
# KOI_Name
# K00752.01                     -2.775000e-05            170.538750
# K00752.02                     -2.479000e-04            162.513840
# K00753.01                     -1.494000e-05            175.850252
# K00754.01                     -2.630000e-07            170.307565
# K00755.01                     -3.761000e-06            171.595550
# ...                                     ...                   ...
# K07985.01                     -1.160000e-07            131.705093
# K07986.01                     -1.780000e-05            133.001270
# K07987.01                     -2.434000e-06            132.181750
# K07988.01                     -4.235000e-03            153.615010
# K07989.01                     -6.356000e-05            135.993300
#
#            Transit_Epoch_Upper_Unc._[BKJD]  Transit_Epoch_Lower_Unc._[BKJD]  \
# KOI_Name
# K00752.01                         0.002160                        -0.002160
# K00752.02                         0.003520                        -0.003520
# K00753.01                         0.000581                        -0.000581
# K00754.01                         0.000115                        -0.000115
# K00755.01                         0.001130                        -0.001130
# ...                                    ...                              ...
# K07985.01                         0.000170                        -0.000170
# K07986.01                         0.007690                        -0.007690
# K07987.01                         0.002850                        -0.002850
# K07988.01                         0.005070                        -0.005070
# K07989.01                         0.010800                        -0.010800
#
#            Impact_Parameter  Impact_Parameter_Upper_Unc.  \
# KOI_Name
# K00752.01             0.146                        0.318
# K00752.02             0.586                        0.059
# K00753.01             0.969                        5.126
# K00754.01             1.276                        0.115
# K00755.01             0.701                        0.235
# ...                     ...                          ...
# K07985.01             1.252                        0.051
# K07986.01             0.043                        0.423
# K07987.01             0.147                        0.309
# K07988.01             0.214                        0.255
# K07989.01             0.134                        0.323
#
#            Impact_Parameter_Lower_Unc.  Transit_Duration_[hrs]  ...  \
# KOI_Name                                                        ...
# K00752.01                       -0.146                 2.95750  ...
# K00752.02                       -0.443                 4.50700  ...
# K00753.01                       -0.077                 1.78220  ...
# K00754.01                       -0.092                 2.40641  ...
# K00755.01                       -0.478                 1.65450  ...
# ...                                ...                     ...  ...
# K07985.01                       -0.049                 3.22210  ...
# K07986.01                       -0.043                 3.11400  ...
# K07987.01                       -0.147                 0.86500  ...
# K07988.01                       -0.214                 3.19900  ...
# K07989.01                       -0.134                 3.07800  ...
#
#            Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                     4.467
# K00752.02                                     4.467
# K00753.01                                     4.544
# K00754.01                                     4.564
# K00755.01                                     4.438
# ...                                             ...
# K07985.01                                     4.529
# K07986.01                                     4.444
# K07987.01                                     4.447
# K07988.01                                     2.992
# K07989.01                                     4.385
#
#            Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                              0.064
# K00752.02                                              0.064
# K00753.01                                              0.044
# K00754.01                                              0.053
# K00755.01                                              0.070
# ...                                                      ...
# K07985.01                                              0.035
# K07986.01                                              0.056
# K07987.01                                              0.056
# K07988.01                                              0.030
# K07989.01                                              0.054
#
#            Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# KOI_Name
# K00752.01                                             -0.096
# K00752.02                                             -0.096
# K00753.01                                             -0.176
# K00754.01                                             -0.168
# K00755.01                                             -0.210
# ...                                                      ...
# K07985.01                                             -0.196
# K07986.01                                             -0.224
# K07987.01                                             -0.224
# K07988.01                                             -0.027
# K07989.01                                             -0.216
#
#            Stellar_Radius_[Solar_radii]  \
# KOI_Name
# K00752.01                         0.927
# K00752.02                         0.927
# K00753.01                         0.868
# K00754.01                         0.791
# K00755.01                         1.046
# ...                                 ...
# K07985.01                         0.903
# K07986.01                         1.031
# K07987.01                         1.041
# K07988.01                         7.824
# K07989.01                         1.193
#
#            Stellar_Radius_Upper_Unc._[Solar_radii]  \
# KOI_Name
# K00752.01                                    0.105
# K00752.02                                    0.105
# K00753.01                                    0.233
# K00754.01                                    0.201
# K00755.01                                    0.334
# ...                                            ...
# K07985.01                                    0.237
# K07986.01                                    0.341
# K07987.01                                    0.341
# K07988.01                                    0.223
# K07989.01                                    0.410
#
#            Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# KOI_Name
# K00752.01                                   -0.061             291.93423
# K00752.02                                   -0.061             291.93423
# K00753.01                                   -0.078             297.00482
# K00754.01                                   -0.067             285.53461
# K00755.01                                   -0.133             288.75488
# ...                                            ...                   ...
# K07985.01                                   -0.079             297.18875
# K07986.01                                   -0.114             286.50937
# K07987.01                                   -0.114             294.16489
# K07988.01                                   -1.896             296.76288
# K07989.01                                   -0.137             297.00977
#
#            Dec_[decimal_degrees]  Kepler-band_[mag]  \
# KOI_Name
# K00752.01              48.141651             15.347
# K00752.02              48.141651             15.347
# K00753.01              48.134129             15.436
# K00754.01              48.285210             15.597
# K00755.01              48.226200             15.509
# ...                          ...                ...
# K07985.01              47.093819             14.082
# K07986.01              47.163219             14.757
# K07987.01              47.176281             15.385
# K07988.01              47.145142             10.998
# K07989.01              47.121021             14.826
#
#            Exoplanet_Archive_Disposition_CONFIRMED
# KOI_Name
# K00752.01                                      1.0
# K00752.02                                      1.0
# K00753.01                                      0.0
# K00754.01                                      0.0
# K00755.01                                      1.0
# ...                                            ...
# K07985.01                                      0.0
# K07986.01                                      0.0
# K07987.01                                      0.0
# K07988.01                                      0.0
# K07989.01                                      0.0
#
# [9564 rows x 36 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = new_planets_df.Exoplanet_Archive_Disposition_CONFIRMED
X = new_planets_df.drop(columns= ["Exoplanet_Archive_Disposition_CONFIRMED"] )

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                2880
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,341
# Trainable params: 5,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq= "epoch")

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, callbacks=[cp_callback])
# Out:
# Epoch 1/50
# 170/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7230
# Epoch 00001: saving model to checkpoints\weights.01.hdf5
# 225/225 [==============================] - 0s 795us/step - loss: nan - accuracy: 0.7208
# Epoch 2/50
# 161/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7137
# Epoch 00002: saving model to checkpoints\weights.02.hdf5
# 225/225 [==============================] - 0s 766us/step - loss: nan - accuracy: 0.7212
# Epoch 3/50
# 166/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7227
# Epoch 00003: saving model to checkpoints\weights.03.hdf5
# 225/225 [==============================] - 0s 830us/step - loss: nan - accuracy: 0.7212
# Epoch 4/50
# 158/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7193
# Epoch 00004: saving model to checkpoints\weights.04.hdf5
# 225/225 [==============================] - 0s 827us/step - loss: nan - accuracy: 0.7212
# Epoch 5/50
# 160/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7158
# Epoch 00005: saving model to checkpoints\weights.05.hdf5
# 225/225 [==============================] - 0s 842us/step - loss: nan - accuracy: 0.7212
# Epoch 6/50
# 162/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7201
# Epoch 00006: saving model to checkpoints\weights.06.hdf5
# 225/225 [==============================] - 0s 750us/step - loss: nan - accuracy: 0.7212
# Epoch 7/50
# 166/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7221
# Epoch 00007: saving model to checkpoints\weights.07.hdf5
# 225/225 [==============================] - 0s 802us/step - loss: nan - accuracy: 0.7212
# Epoch 8/50
# 162/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7216
# Epoch 00008: saving model to checkpoints\weights.08.hdf5
# 225/225 [==============================] - 0s 860us/step - loss: nan - accuracy: 0.7212
# Epoch 9/50
# 170/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7191
# Epoch 00009: saving model to checkpoints\weights.09.hdf5
# 225/225 [==============================] - 0s 738us/step - loss: nan - accuracy: 0.7212
# Epoch 10/50
# 169/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7182
# Epoch 00010: saving model to checkpoints\weights.10.hdf5
# 225/225 [==============================] - 0s 744us/step - loss: nan - accuracy: 0.7212
# Epoch 11/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7269
# Epoch 00011: saving model to checkpoints\weights.11.hdf5
# 225/225 [==============================] - 0s 727us/step - loss: nan - accuracy: 0.7212
# Epoch 12/50
# 164/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7208
# Epoch 00012: saving model to checkpoints\weights.12.hdf5
# 225/225 [==============================] - 0s 794us/step - loss: nan - accuracy: 0.7212
# Epoch 13/50
# 197/225 [=========================>....] - ETA: 0s - loss: nan - accuracy: 0.7181
# Epoch 00013: saving model to checkpoints\weights.13.hdf5
# 225/225 [==============================] - 0s 889us/step - loss: nan - accuracy: 0.7212
# Epoch 14/50
# 152/225 [===================>..........] - ETA: 0s - loss: nan - accuracy: 0.7251
# Epoch 00014: saving model to checkpoints\weights.14.hdf5
# 225/225 [==============================] - 0s 811us/step - loss: nan - accuracy: 0.7212
# Epoch 15/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7160
# Epoch 00015: saving model to checkpoints\weights.15.hdf5
# 225/225 [==============================] - 0s 763us/step - loss: nan - accuracy: 0.7212
# Epoch 16/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7260
# Epoch 00016: saving model to checkpoints\weights.16.hdf5
# 225/225 [==============================] - 0s 819us/step - loss: nan - accuracy: 0.7212
# Epoch 17/50
# 167/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7180
# Epoch 00017: saving model to checkpoints\weights.17.hdf5
# 225/225 [==============================] - 0s 720us/step - loss: nan - accuracy: 0.7212
# Epoch 18/50
# 169/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7151
# Epoch 00018: saving model to checkpoints\weights.18.hdf5
# 225/225 [==============================] - 0s 766us/step - loss: nan - accuracy: 0.7212
# Epoch 19/50
# 159/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7182
# Epoch 00019: saving model to checkpoints\weights.19.hdf5
# 225/225 [==============================] - 0s 744us/step - loss: nan - accuracy: 0.7212
# Epoch 20/50
# 162/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7203
# Epoch 00020: saving model to checkpoints\weights.20.hdf5
# 225/225 [==============================] - 0s 749us/step - loss: nan - accuracy: 0.7212
# Epoch 21/50
# 163/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7141
# Epoch 00021: saving model to checkpoints\weights.21.hdf5
# 225/225 [==============================] - 0s 794us/step - loss: nan - accuracy: 0.7212
# Epoch 22/50
# 164/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7250
# Epoch 00022: saving model to checkpoints\weights.22.hdf5
# 225/225 [==============================] - 0s 844us/step - loss: nan - accuracy: 0.7212
# Epoch 23/50
# 157/225 [===================>..........] - ETA: 0s - loss: nan - accuracy: 0.7203
# Epoch 00023: saving model to checkpoints\weights.23.hdf5
# 225/225 [==============================] - 0s 860us/step - loss: nan - accuracy: 0.7212
# Epoch 24/50
# 166/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7220
# Epoch 00024: saving model to checkpoints\weights.24.hdf5
# 225/225 [==============================] - 0s 771us/step - loss: nan - accuracy: 0.7212
# Epoch 25/50
# 164/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7205
# Epoch 00025: saving model to checkpoints\weights.25.hdf5
# 225/225 [==============================] - 0s 743us/step - loss: nan - accuracy: 0.7212
# Epoch 26/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7197
# Epoch 00026: saving model to checkpoints\weights.26.hdf5
# 225/225 [==============================] - 0s 741us/step - loss: nan - accuracy: 0.7212
# Epoch 27/50
# 169/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7234
# Epoch 00027: saving model to checkpoints\weights.27.hdf5
# 225/225 [==============================] - 0s 730us/step - loss: nan - accuracy: 0.7212
# Epoch 28/50
# 165/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7180
# Epoch 00028: saving model to checkpoints\weights.28.hdf5
# 225/225 [==============================] - 0s 708us/step - loss: nan - accuracy: 0.7212
# Epoch 29/50
# 169/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7221
# Epoch 00029: saving model to checkpoints\weights.29.hdf5
# 225/225 [==============================] - 0s 699us/step - loss: nan - accuracy: 0.7212
# Epoch 30/50
# 166/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7255
# Epoch 00030: saving model to checkpoints\weights.30.hdf5
# 225/225 [==============================] - 0s 727us/step - loss: nan - accuracy: 0.7212
# Epoch 31/50
# 171/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7177
# Epoch 00031: saving model to checkpoints\weights.31.hdf5
# 225/225 [==============================] - 0s 729us/step - loss: nan - accuracy: 0.7212
# Epoch 32/50
# 171/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7204
# Epoch 00032: saving model to checkpoints\weights.32.hdf5
# 225/225 [==============================] - 0s 707us/step - loss: nan - accuracy: 0.7212
# Epoch 33/50
# 170/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7239
# Epoch 00033: saving model to checkpoints\weights.33.hdf5
# 225/225 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.7212
# Epoch 34/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7260
# Epoch 00034: saving model to checkpoints\weights.34.hdf5
# 225/225 [==============================] - 0s 768us/step - loss: nan - accuracy: 0.7212
# Epoch 35/50
# 167/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7246
# Epoch 00035: saving model to checkpoints\weights.35.hdf5
# 225/225 [==============================] - 0s 737us/step - loss: nan - accuracy: 0.7212
# Epoch 36/50
# 167/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7253
# Epoch 00036: saving model to checkpoints\weights.36.hdf5
# 225/225 [==============================] - 0s 788us/step - loss: nan - accuracy: 0.7212
# Epoch 37/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7184
# Epoch 00037: saving model to checkpoints\weights.37.hdf5
# 225/225 [==============================] - 0s 770us/step - loss: nan - accuracy: 0.7212
# Epoch 38/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7199
# Epoch 00038: saving model to checkpoints\weights.38.hdf5
# 225/225 [==============================] - 0s 817us/step - loss: nan - accuracy: 0.7212
# Epoch 39/50
# 167/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7221
# Epoch 00039: saving model to checkpoints\weights.39.hdf5
# 225/225 [==============================] - 0s 831us/step - loss: nan - accuracy: 0.7212
# Epoch 40/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7214
# Epoch 00040: saving model to checkpoints\weights.40.hdf5
# 225/225 [==============================] - 0s 717us/step - loss: nan - accuracy: 0.7212
# Epoch 41/50
# 169/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7223
# Epoch 00041: saving model to checkpoints\weights.41.hdf5
# 225/225 [==============================] - 0s 759us/step - loss: nan - accuracy: 0.7212
# Epoch 42/50
# 159/225 [====================>.........] - ETA: 0s - loss: nan - accuracy: 0.7193
# Epoch 00042: saving model to checkpoints\weights.42.hdf5
# 225/225 [==============================] - 0s 842us/step - loss: nan - accuracy: 0.7212
# Epoch 43/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7188
# Epoch 00043: saving model to checkpoints\weights.43.hdf5
# 225/225 [==============================] - 0s 761us/step - loss: nan - accuracy: 0.7212
# Epoch 44/50
# 169/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7224
# Epoch 00044: saving model to checkpoints\weights.44.hdf5
# 225/225 [==============================] - 0s 695us/step - loss: nan - accuracy: 0.7212
# Epoch 45/50
# 177/225 [======================>.......] - ETA: 0s - loss: nan - accuracy: 0.7219
# Epoch 00045: saving model to checkpoints\weights.45.hdf5
# 225/225 [==============================] - 0s 971us/step - loss: nan - accuracy: 0.7212
# Epoch 46/50
# 224/225 [============================>.] - ETA: 0s - loss: nan - accuracy: 0.7217
# Epoch 00046: saving model to checkpoints\weights.46.hdf5
# 225/225 [==============================] - 0s 882us/step - loss: nan - accuracy: 0.7212
# Epoch 47/50
# 166/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7155
# Epoch 00047: saving model to checkpoints\weights.47.hdf5
# 225/225 [==============================] - 0s 721us/step - loss: nan - accuracy: 0.7212
# Epoch 48/50
# 170/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7206
# Epoch 00048: saving model to checkpoints\weights.48.hdf5
# 225/225 [==============================] - 0s 699us/step - loss: nan - accuracy: 0.7212
# Epoch 49/50
# 170/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7180
# Epoch 00049: saving model to checkpoints\weights.49.hdf5
# 225/225 [==============================] - 0s 695us/step - loss: nan - accuracy: 0.7212
# Epoch 50/50
# 168/225 [=====================>........] - ETA: 0s - loss: nan - accuracy: 0.7176
# Epoch 00050: saving model to checkpoints\weights.50.hdf5
# 225/225 [==============================] - 0s 785us/step - loss: nan - accuracy: 0.7212
