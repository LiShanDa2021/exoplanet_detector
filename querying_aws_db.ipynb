# %%
#import config
import psycopg2
from config import *

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, MetaData, Table

import sqlalchemy

engine = sqlalchemy.create_engine(database_url)
connection = engine.connect()

# Declare a Base using `automap_base()`
Base = automap_base()
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['confirmed_planets1', 'false_planets']

# %%
false_planets_df = pd.read_sql_table('false_planets', engine)
false_planets_df
# Out:
#        koi_name exoplanet_archive_disposition  orbital_period  transit_epoch  \
# 0     K00752.01                     CONFIRMED        9.488036     170.538750
# 1     K00752.02                     CONFIRMED       54.418383     162.513840
# 2     K00754.01                FALSE POSITIVE        1.736952     170.307565
# 3     K00755.01                     CONFIRMED        2.525592     171.595550
# 4     K00756.01                     CONFIRMED       11.094321     171.201160
# ...         ...                           ...             ...            ...
# 7242  K08198.01                FALSE POSITIVE      373.893980     261.496800
# 7243  K07984.01                FALSE POSITIVE        8.589871     132.016100
# 7244  K07985.01                FALSE POSITIVE        0.527699     131.705093
# 7245  K07987.01                FALSE POSITIVE        0.681402     132.181750
# 7246  K07989.01                FALSE POSITIVE        4.856035     135.993300
#
# ...

# %%
import pandas as pd

# %%
planets_df = pd.read_sql_table('confirmed_planets1', engine)
planets_df

# %%
metadata = MetaData()

# %%
# Create a table object and use 'autoload' and 'autoload_with' to define the columns from the table. 
table = Table('confirmed_planets1', metadata, autoload=True, autoload_with=engine)

# %%
# Get the column names using the 'keys()' method on the column object. 
table.columns.keys()

# %%
table.columns.orbital_period

# %%
planet_table = pd.read_table(table)

# %%
connection.close()

# %%
# scrap code
conn = psycopg2.connect(dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=5432)
#conn = psycopg2.connect(dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=5432)
cur = conn.cursor()
cur.execute("SELECT * FROM confirmed_planets1;")
print(cur.fetchall())
conn.commit()

# %%
cur.close()
conn.close()

# %%
inspector = inspect(engine)

# %%
data = engine.execute("SELECT * FROM confirmed_planets1 limit 10")

for record in data:
    print(record)

# %%
columns = inspector.get_columns('confirmed_planets1')
for column in columns:
    print(column["name"], column["type"])
