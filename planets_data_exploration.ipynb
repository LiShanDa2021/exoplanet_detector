# %%
import pandas as pd
import os

# %%
large_file = pd.read_csv("32k_exoplanet_file.csv")
big_planets_df = pd.DataFrame(large_file)
big_planets_df
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             1        2        1  Radial Velocity
# 1       11 Com b   11 Com             0        2        1  Radial Velocity
# 2       11 UMi b   11 UMi             0        1        1  Radial Velocity
# 3       11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             0        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 32068  ups And d  ups And             0        2        3  Radial Velocity
# 32069  ups And d  ups And             0        2        3  Radial Velocity
# 32070  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 32071   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 32072   xi Aql b   xi Aql             1        1        1  Radial Velocity
#
# ...

# %%
big_planet_column_names = pd.read_csv("32k_column_names.csv")
big_planet_column_names
# Out:
#                                                  0
# 0                                      Planet_Name
# 1                                        Host_Name
# 2                            Default_Parameter_Set
# 3                                  Number_of_Stars
# 4                                Number_of_Planets
# ..                                             ...
# 87                        Gaia_Magnitude_Upper_Unc
# 88                        Gaia_Magnitude_Lower_Unc
# 89                             Date_of_Last_Update
# 90  Planetary_Parameter_Reference_Publication_Date
# 91                                    Release_Date
#
# [92 rows x 1 columns]

# %%
big_planet_column_names=big_planet_column_names['0']
big_planet_column_names=big_planet_column_names.to_list()
big_planet_column_names
# Out:
# ['Planet_Name',
#  'Host_Name',
#  'Default_Parameter_Set',
#  'Number_of_Stars',
#  'Number_of_Planets',
#  'Discovery_Method',
#  'Discovery_Year',
#  'Discovery_Facility',
#  'Solution_Type',
#  'Controversial_Flag',
#  'Planetary_Parameter_Reference',
#  'Orbital_Period_[days]',
#  'Orbital_Period_Upper_Unc._[days]',
#  'Orbital_Period_Lower_Unc._[days]',
#  'Orbital_Period_Limit_Flag',
#  'Orbit_Semi-Major_Axis_[au])',
#  'Orbit_Semi-Major_Axis_Upper_Unc._[au]',
#  'Orbit_Semi-Major_Axis_Lower_Unc._[au]',
#  'Orbit_Semi-Major_Axis_Limit_Flag',
#  'Planet_Radius_[Earth_Radius]',
#  'Planet_Radius_Upper_Unc._[Earth_Radius]',
#  'Planet_Radius_Lower_Unc._[Earth_Radius]',
#  'Planet_Radius_Limit_Flag',
#  'Planet_Radius_[Jupiter_Radius]',
#  'Planet_Radius_Upper_Unc._[Jupiter_Radius]',
#  'Planet_Radius_Lower_Unc._[Jupiter_Radius]',
#  'Planet_Radius_Limit_Flag',
#  'Planet_Mass_or_Mass*sin(i)_[Earth_Mass]',
#  'Planet_Mass_or_Mass*sin(i)_[Earth_Mass]_Upper_Unc.',
# ...

# %%
len(big_planet_column_names)
# Out:
# 92

# %%
big_planets_df.columns = big_planet_column_names

# %%
big_planets_df
# Out:
#       Planet_Name Host_Name  Default_Parameter_Set  Number_of_Stars  \
# 0        11 Com b    11 Com                      1                2
# 1        11 Com b    11 Com                      0                2
# 2        11 UMi b    11 UMi                      0                1
# 3        11 UMi b    11 UMi                      1                1
# 4        11 UMi b    11 UMi                      0                1
# ...           ...       ...                    ...              ...
# 32068   ups And d   ups And                      0                2
# 32069   ups And d   ups And                      0                2
# 32070   ups Leo b   ups Leo                      1                1
# 32071    xi Aql b    xi Aql                      0                1
# 32072    xi Aql b    xi Aql                      1                1
#
#        Number_of_Planets Discovery_Method  Discovery_Year  \
# 0                      1  Radial Velocity            2007
# ...

# %%
big_planets_df.Discovery_Facility.unique()
# Out:
# array(['Xinglong Station', 'Thueringer Landessternwarte Tautenburg',
#        'Okayama Astrophysical Observatory', 'W. M. Keck Observatory',
#        'Multiple Observatories', 'Lick Observatory', 'Gemini Observatory',
#        'Subaru Telescope', 'Paranal Observatory',
#        'Cerro Tololo Inter-American Observatory',
#        'Hubble Space Telescope', 'Kepler', 'Haute-Provence Observatory',
#        'McDonald Observatory', 'Anglo-Australian Telescope',
#        'Bohyunsan Optical Astronomical Observatory',
#        'Transiting Exoplanet Survey Satellite (TESS)',
#        'Roque de los Muchachos Observatory', 'K2',
#        'Wide-field Infrared Survey Explorer (WISE) Sat',
#        'La Silla Observatory', 'Calar Alto Observatory',
#        'NASA Infrared Telescope Facility (IRTF)', 'CoRoT',
#        'Multiple Facilities', 'Yunnan Astronomical Observatory',
#        'Spitzer Space Telescope', 'MEarth Project',
# ...

# %%
big_planets_df = big_planets_df.loc[big_planets_df['Discovery_Facility']=='Kepler']
big_planets_df
# Out:
#                      Planet_Name                Host_Name  \
# 38     2MASS J19383260+4603591 b  2MASS J19383260+4603591
# 4254              KIC 10001893 b             KIC 10001893
# 4255              KIC 10001893 c             KIC 10001893
# 4256              KIC 10001893 d             KIC 10001893
# 4257              KIC 10068024 b             KIC 10068024
# ...                          ...                      ...
# 30788                      PH2 b                      PH2
# 30789                      PH2 b                      PH2
# 30790                      PH2 b                      PH2
# 30791                      PH2 b                      PH2
# 30792                      PH2 b                      PH2
#
#        Default_Parameter_Set  Number_of_Stars  Number_of_Planets  \
# 38                         1                2                  1
# 4254                       1                1                  3
# 4255                       1                1                  3
# ...

# %%
len(big_planets_df.columns)
big_planets_df.columns
# Out:
# Index(['Planet_Name', 'Host_Name', 'Default_Parameter_Set', 'Number_of_Stars',
#        'Number_of_Planets', 'Discovery_Method', 'Discovery_Year',
#        'Discovery_Facility', 'Solution_Type', 'Controversial_Flag',
#        'Planetary_Parameter_Reference', 'Orbital_Period_[days]',
#        'Orbital_Period_Upper_Unc._[days]', 'Orbital_Period_Lower_Unc._[days]',
#        'Orbital_Period_Limit_Flag', 'Orbit_Semi-Major_Axis_[au])',
#        'Orbit_Semi-Major_Axis_Upper_Unc._[au]',
#        'Orbit_Semi-Major_Axis_Lower_Unc._[au]',
#        'Orbit_Semi-Major_Axis_Limit_Flag', 'Planet_Radius_[Earth_Radius]',
#        'Planet_Radius_Upper_Unc._[Earth_Radius]',
#        'Planet_Radius_Lower_Unc._[Earth_Radius]', 'Planet_Radius_Limit_Flag',
#        'Planet_Radius_[Jupiter_Radius]',
#        'Planet_Radius_Upper_Unc._[Jupiter_Radius]',
#        'Planet_Radius_Lower_Unc._[Jupiter_Radius]', 'Planet_Radius_Limit_Flag',
#        'Planet_Mass_or_Mass*sin(i)_[Earth_Mass]',
# ...

# %%
file = pd.read_csv("kepler_data.csv")

planets_df = pd.DataFrame(file)
planets_df
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560  10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562  10155286  K07988.01           NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %%
planets_df.columns
# Out:
# Index(['kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
len(planets_df.columns)
# Out:
# 49

# %%
# clean planet columns in excel before proceeding

# %%
#read in csv of cleaned column names
planet_column_names = pd.read_csv("planet_columns.csv")
planet_column_names = planet_column_names.df_columns
planet_column_names = planet_column_names.to_list()
planet_column_names
# Out:
# ['KepID',
#  'KOI_Name',
#  'Kepler_Name',
#  'Exoplanet_Archive_Disposition',
#  'Disposition_Using_Kepler_Data',
#  'Disposition_Score',
#  'Not_Transit-Like_False_Positive_Flag',
#  'Stellar_Eclipse_False_Positive_Flag',
#  'Centroid_Offset_False_Positive_Flag',
#  'Ephemeris_Match_Indicates_Contamination_False_Positive_Flag',
#  'Orbital_Period_[days]',
#  'Orbital_Period_Upper_Unc._[days]',
#  'Orbital_Period_Lower_Unc._[days]',
#  'Transit_Epoch_[BKJD]',
#  'Transit_Epoch_Upper_Unc._[BKJD]',
#  'Transit_Epoch_Lower_Unc._[BKJD]',
#  'Impact_Parameter',
#  'Impact_Parameter_Upper_Unc.',
#  'Impact_Parameter_Lower_Unc.',
#  'Transit_Duration_[hrs]',
#  'Transit_Duration_Upper_Unc._[hrs]',
#  'Transit_Duration_Lower_Unc._[hrs]',
#  'Transit_Depth_[ppm]',
#  'Transit_Depth_Upper_Unc._[ppm]',
#  'Transit_Depth_Lower_Unc._[ppm]',
#  'Planetary_Radius_[Earth_radii]',
#  'Planetary_Radius_Upper_Unc._[Earth_radii]',
#  'Planetary_Radius_Lower_Unc._[Earth_radii]',
# ...

# %%
#replace df column names with more legible columns
planets_df.columns = planet_column_names

# %%
planets_df
# Out:
#          KepID   KOI_Name   Kepler_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01  Kepler-227 b                     CONFIRMED
# 1     10797460  K00752.02  Kepler-227 c                     CONFIRMED
# 2     10811496  K00753.01           NaN                     CANDIDATE
# 3     10848459  K00754.01           NaN                FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b                     CONFIRMED
# ...        ...        ...           ...                           ...
# 9559  10090151  K07985.01           NaN                FALSE POSITIVE
# 9560  10128825  K07986.01           NaN                     CANDIDATE
# 9561  10147276  K07987.01           NaN                FALSE POSITIVE
# 9562  10155286  K07988.01           NaN                     CANDIDATE
# 9563  10156110  K07989.01           NaN                FALSE POSITIVE
#
#      Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                        CANDIDATE              1.000
# ...

# %%
#find out the number of solution types
planets_df.Exoplanet_Archive_Disposition.unique()
# Out:
# array(['CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
# save the kepler names for later maybe
kep_names = planets_df.Kepler_Name
kep_names
# Out:
# 0       Kepler-227 b
# 1       Kepler-227 c
# 2                NaN
# 3                NaN
# 4       Kepler-664 b
#             ...
# 9559             NaN
# 9560             NaN
# 9561             NaN
# 9562             NaN
# 9563             NaN
# Name: Kepler_Name, Length: 9564, dtype: object

# %%
# should we drop the disposition using kepler since it's kind of redundant?

# %%
planets_df.isna()
# Out:
#       KepID  KOI_Name  Kepler_Name  Exoplanet_Archive_Disposition  \
# 0     False     False        False                          False
# 1     False     False        False                          False
# 2     False     False         True                          False
# 3     False     False         True                          False
# 4     False     False        False                          False
# ...     ...       ...          ...                            ...
# 9559  False     False         True                          False
# 9560  False     False         True                          False
# 9561  False     False         True                          False
# 9562  False     False         True                          False
# 9563  False     False         True                          False
#
#       Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                             False              False
# 1                             False              False
# ...

# %%
# need to drop all columns that presuppose object is a planet
# as well as columns with too many NaNs

# %%
planets_df.Kepler_Name.isna().sum()
# Out:
# 6896

# %%
planets_df.Kepler_Name.isna().sum()/len(planets_df.Kepler_Name)
# Out:
# 0.7210372229192806

# %%
# identify columns that are more than 20% empty
empty_columns = []
for column in planets_df:
    column_name=column
    if (planets_df[column].isna().sum()/len(planets_df[column]) > 0.20):
        empty_columns.append(column_name)

empty_columns
# Out:
# ['Kepler_Name',
#  'Equilibrium_Temperature_Upper_Unc._[K]',
#  'Equilibrium_Temperature_Lower_Unc._[K]']

# %%
planets_df=planets_df.drop(columns=empty_columns, axis=1)

# %%
planets_df
# Out:
#          KepID   KOI_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01                     CONFIRMED
# 1     10797460  K00752.02                     CONFIRMED
# 2     10811496  K00753.01                     CANDIDATE
# 3     10848459  K00754.01                FALSE POSITIVE
# 4     10854555  K00755.01                     CONFIRMED
# ...        ...        ...                           ...
# 9559  10090151  K07985.01                FALSE POSITIVE
# 9560  10128825  K07986.01                     CANDIDATE
# 9561  10147276  K07987.01                FALSE POSITIVE
# 9562  10155286  K07988.01                     CANDIDATE
# 9563  10156110  K07989.01                FALSE POSITIVE
#
#      Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                        CANDIDATE              1.000
# 1                        CANDIDATE              0.969
# 2                        CANDIDATE              0.000
# 3                   FALSE POSITIVE              0.000
# ...

# %%
# drop disposition using kepler data and disposition score -- because that's actually what we are trying to create
# Exoplanet_Archive_Disposition will ultimately be our target
planets_df=planets_df.drop(columns=['Disposition_Using_Kepler_Data','Disposition_Score'], axis=1)
planets_df
# Out:
#          KepID   KOI_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01                     CONFIRMED
# 1     10797460  K00752.02                     CONFIRMED
# 2     10811496  K00753.01                     CANDIDATE
# 3     10848459  K00754.01                FALSE POSITIVE
# 4     10854555  K00755.01                     CONFIRMED
# ...        ...        ...                           ...
# 9559  10090151  K07985.01                FALSE POSITIVE
# 9560  10128825  K07986.01                     CANDIDATE
# 9561  10147276  K07987.01                FALSE POSITIVE
# 9562  10155286  K07988.01                     CANDIDATE
# 9563  10156110  K07989.01                FALSE POSITIVE
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...

# %%
planets_df['Not_Transit-Like_False_Positive_Flag'].unique()
# Out:
# array([  0,   1, 465])

# %%
# drop False_Positive_Flag columns because they are basically giving us the answer we are trying to calculate
planets_df=planets_df.drop(columns=['Not_Transit-Like_False_Positive_Flag','Stellar_Eclipse_False_Positive_Flag', 'Centroid_Offset_False_Positive_Flag', 'Ephemeris_Match_Indicates_Contamination_False_Positive_Flag'], axis=1)

# %%
planets_df
# Out:
#          KepID   KOI_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01                     CONFIRMED
# 1     10797460  K00752.02                     CONFIRMED
# 2     10811496  K00753.01                     CANDIDATE
# 3     10848459  K00754.01                FALSE POSITIVE
# 4     10854555  K00755.01                     CONFIRMED
# ...        ...        ...                           ...
# 9559  10090151  K07985.01                FALSE POSITIVE
# 9560  10128825  K07986.01                     CANDIDATE
# 9561  10147276  K07987.01                FALSE POSITIVE
# 9562  10155286  K07988.01                     CANDIDATE
# 9563  10156110  K07989.01                FALSE POSITIVE
#
#       Orbital_Period_[days]  Orbital_Period_Upper_Unc._[days]  \
# 0                  9.488036                      2.775000e-05
# 1                 54.418383                      2.479000e-04
# 2                 19.899140                      1.494000e-05
# ...

# %%
# find out how many of each disposition there are in Exoplanet_Archive_Disposition
planets_df.Exoplanet_Archive_Disposition.value_counts()
# Out:
# FALSE POSITIVE    4840
# CONFIRMED         2666
# CANDIDATE         2058
# Name: Exoplanet_Archive_Disposition, dtype: int64

# %%
# find the biggest star 	Stellar_Radius_[Solar_radii]
planets_df['Stellar_Radius_[Solar_radii]'].sort_values(ascending=False)
# Out:
# 8453    229.908
# 4976    180.013
# 7917    162.725
# 5545    152.969
# 9229    151.184
#          ...
# 9348        NaN
# 9393        NaN
# 9406        NaN
# 9501        NaN
# 9517        NaN
# Name: Stellar_Radius_[Solar_radii], Length: 9564, dtype: float64

# %%
# find the smallest star 	Stellar_Radius_[Solar_radii]
planets_df['Stellar_Radius_[Solar_radii]'].sort_values(ascending=True)
# Out:
# 8530    0.109
# 3739    0.116
# 9222    0.116
# 2567    0.116
# 633     0.116
#         ...
# 9348      NaN
# 9393      NaN
# 9406      NaN
# 9501      NaN
# 9517      NaN
# Name: Stellar_Radius_[Solar_radii], Length: 9564, dtype: float64

# %%
planets_df.columns
# Out:
# Index(['KepID', 'KOI_Name', 'Exoplanet_Archive_Disposition',
#        'Orbital_Period_[days]', 'Orbital_Period_Upper_Unc._[days]',
#        'Orbital_Period_Lower_Unc._[days]', 'Transit_Epoch_[BKJD]',
#        'Transit_Epoch_Upper_Unc._[BKJD]', 'Transit_Epoch_Lower_Unc._[BKJD]',
#        'Impact_Parameter', 'Impact_Parameter_Upper_Unc.',
#        'Impact_Parameter_Lower_Unc.', 'Transit_Duration_[hrs]',
#        'Transit_Duration_Upper_Unc._[hrs]',
#        'Transit_Duration_Lower_Unc._[hrs]', 'Transit_Depth_[ppm]',
#        'Transit_Depth_Upper_Unc._[ppm]', 'Transit_Depth_Lower_Unc._[ppm]',
#        'Planetary_Radius_[Earth_radii]',
#        'Planetary_Radius_Upper_Unc._[Earth_radii]',
#        'Planetary_Radius_Lower_Unc._[Earth_radii]',
#        'Equilibrium_Temperature_[K]', 'Insolation_Flux_[Earth_flux]',
#        'Insolation_Flux_Upper_Unc._[Earth_flux]',
#        'Insolation_Flux_Lower_Unc._[Earth_flux]', 'Transit_Signal-to-Noise',
#        'TCE_Planet_Number', 'TCE_Delivery',
# ...

# %%
len(planets_df.columns)
# Out:
# 40

# %%
# find the biggest planet
planets_df['Planetary_Radius_[Earth_radii]'].sort_values(ascending=False)
# Out:
# 8893    200346.0
# 8747    161858.0
# 7151    109061.0
# 8529     64333.8
# 6336     46743.4
#           ...
# 9348         NaN
# 9393         NaN
# 9406         NaN
# 9501         NaN
# 9517         NaN
# Name: Planetary_Radius_[Earth_radii], Length: 9564, dtype: float64

# %%
len(planets_df['KepID'].unique())
# Out:
# 8214

# %%
len(planets_df['KOI_Name'].unique())
# Out:
# 9564

# %%
# drop KepID since it isn't unique and isn't predictive
planets_df=planets_df.drop(columns=['KepID'], axis=1)
planets_df
# Out:
#        KOI_Name Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# 0     K00752.01                     CONFIRMED               9.488036
# 1     K00752.02                     CONFIRMED              54.418383
# 2     K00753.01                     CANDIDATE              19.899140
# 3     K00754.01                FALSE POSITIVE               1.736952
# 4     K00755.01                     CONFIRMED               2.525592
# ...         ...                           ...                    ...
# 9559  K07985.01                FALSE POSITIVE               0.527699
# 9560  K07986.01                     CANDIDATE               1.739849
# 9561  K07987.01                FALSE POSITIVE               0.681402
# 9562  K07988.01                     CANDIDATE             333.486169
# 9563  K07989.01                FALSE POSITIVE               4.856035
#
#       Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# ...

# %%
new_planets_df=planets_df.set_index('KOI_Name')
new_planets_df
# Out:
#           Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# KOI_Name
# K00752.01                     CONFIRMED               9.488036
# K00752.02                     CONFIRMED              54.418383
# K00753.01                     CANDIDATE              19.899140
# K00754.01                FALSE POSITIVE               1.736952
# K00755.01                     CONFIRMED               2.525592
# ...                                 ...                    ...
# K07985.01                FALSE POSITIVE               0.527699
# K07986.01                     CANDIDATE               1.739849
# K07987.01                FALSE POSITIVE               0.681402
# K07988.01                     CANDIDATE             333.486169
# K07989.01                FALSE POSITIVE               4.856035
#
#            Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# KOI_Name
# K00752.01                      2.775000e-05                     -2.775000e-05
# ...

# %%
# export to csv
new_planets_df.to_csv("Cleaned_Planet_Exploration_Data.csv")

# %%
# export to json
new_planets_df.to_json('cleaned_planet_exploration_data.json')

# %%
# export the large file
big_planets_df.to_csv("Cleaned__Big_Planet_Exploration_Data.csv")

# %%
confirmed_planets_df = new_planets_df.loc[new_planets_df['Exoplanet_Archive_Disposition']=='CONFIRMED']

# %%
confirmed_planets_df
# Out:
#           Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# KOI_Name
# K00752.01                     CONFIRMED               9.488036
# K00752.02                     CONFIRMED              54.418383
# K00755.01                     CONFIRMED               2.525592
# K00756.01                     CONFIRMED              11.094321
# K00756.02                     CONFIRMED               4.134435
# ...                                 ...                    ...
# K07892.01                     CONFIRMED              10.692115
# K06863.01                     CONFIRMED               4.485592
# K02704.03                     CONFIRMED               8.152759
# K07016.01                     CONFIRMED             384.847556
# K05447.02                     CONFIRMED               3.875943
#
#            Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# KOI_Name
# K00752.01                          0.000028                         -0.000028
# ...

# %%
# Add interesting columns from big dataset to smaller dataset -- empty for now
confirmed_planets_df['Distance_[pc]'] = ""
confirmed_planets_df['Number_of_Stars'] = ""
confirmed_planets_df['Planet_Name'] = ""
confirmed_planets_df['Host_Name'] = ""
confirmed_planets_df
# Out:
# /Users/alexhatheway/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alexhatheway/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alexhatheway/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
# import composite data
composite_df = pd.read_csv("/Users/alexhatheway/Desktop/DataViz/final_project_classes/exoplanet_detector/composite_planet_data.csv")

# %%
composite_df
# Out:
#          pl_name  hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0       11 Com b    11 Com        2        1  Radial Velocity       2007
# 1       11 UMi b    11 UMi        1        1  Radial Velocity       2009
# 2       14 And b    14 And        1        1  Radial Velocity       2008
# 3       14 Her b    14 Her        1        2  Radial Velocity       2002
# 4     16 Cyg B b  16 Cyg B        3        1  Radial Velocity       1996
# ...          ...       ...      ...      ...              ...        ...
# 4909   ups And b   ups And        2        3  Radial Velocity       1996
# 4910   ups And c   ups And        2        3  Radial Velocity       1999
# 4911   ups And d   ups And        2        3  Radial Velocity       1999
# 4912   ups Leo b   ups Leo        1        1  Radial Velocity       2021
# 4913    xi Aql b    xi Aql        1        1  Radial Velocity       2007
#
#                                disc_facility  pl_controv_flag    pl_orbper  \
# ...

# %%
composite_columns = pd.read_csv("/Users/alexhatheway/Desktop/DataViz/final_project_classes/exoplanet_detector/composite_columns.csv")

# %%
composite_columns
# Out:
#                                  0
# 0                      Planet_Name
# 1                        Host_Name
# 2                  Number_of_Stars
# 3                Number_of_Planets
# 4                 Discovery_Method
# ..                             ...
# 79  Ks_(2MASS)_Magnitude_Upper_Unc
# 80  Ks_(2MASS)_Magnitude_Lower_Unc
# 81                  Gaia_Magnitude
# 82        Gaia_Magnitude_Upper_Unc
# 83        Gaia_Magnitude_Lower_Unc
#
# [84 rows x 1 columns]

# %%
composite_df.columns = composite_columns['0']
composite_df
# Out:
# 0    Planet_Name Host_Name  Number_of_Stars  Number_of_Planets  \
# 0       11 Com b    11 Com                2                  1
# 1       11 UMi b    11 UMi                1                  1
# 2       14 And b    14 And                1                  1
# 3       14 Her b    14 Her                1                  2
# 4     16 Cyg B b  16 Cyg B                3                  1
# ...          ...       ...              ...                ...
# 4909   ups And b   ups And                2                  3
# 4910   ups And c   ups And                2                  3
# 4911   ups And d   ups And                2                  3
# 4912   ups Leo b   ups Leo                1                  1
# 4913    xi Aql b    xi Aql                1                  1
#
# 0    Discovery_Method  Discovery_Year                      Discovery_Facility  \
# 0     Radial Velocity            2007                        Xinglong Station
# ...

# %%
composite_df.set_index('Orbital_Period_[days]')
# Out:
# 0                     Planet_Name Host_Name  Number_of_Stars  \
# Orbital_Period_[days]
# 326.030000               11 Com b    11 Com                2
# 516.219970               11 UMi b    11 UMi                1
# 185.840000               14 And b    14 And                1
# 1773.400020              14 Her b    14 Her                1
# 798.500000             16 Cyg B b  16 Cyg B                3
# ...                           ...       ...              ...
# 4.617033                ups And b   ups And                2
# 241.258000              ups And c   ups And                2
# 1276.460000             ups And d   ups And                2
# 385.200000              ups Leo b   ups Leo                1
# 136.750000               xi Aql b    xi Aql                1
#
# 0                      Number_of_Planets Discovery_Method  Discovery_Year  \
# Orbital_Period_[days]
# 326.030000                             1  Radial Velocity            2007
# ...

# %%
composite_df['Discovery_Method'].unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Disk Kinematics',
#        'Orbital Brightness Modulation', 'Pulsation Timing Variations',
#        'Microlensing', 'Transit Timing Variations', 'Pulsar Timing'],
#       dtype=object)

# %%
composite_df.to_csv('composite_cleaned.csv')
