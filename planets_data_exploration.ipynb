# %%
import pandas as pd
import os

# %%
file = pd.read_csv("/Users/alexhatheway/Desktop/PS_2022.01.31_19.12.36.csv")

planets_df = pd.DataFrame(file)
planets_df
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             1        2        1  Radial Velocity
# 1       11 Com b   11 Com             0        2        1  Radial Velocity
# 2       11 UMi b   11 UMi             0        1        1  Radial Velocity
# 3       11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             0        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 32052  ups And d  ups And             0        2        3  Radial Velocity
# 32053  ups And d  ups And             0        2        3  Radial Velocity
# 32054  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 32055   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 32056   xi Aql b   xi Aql             1        1        1  Radial Velocity
#
# ...

# %%
planets_df.columns
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %%
planets_df.soltype.unique()
# Out:
# array(['Published Confirmed', 'TESS Project Candidate',
#        'Published Candidate',
#        'Kepler Project Candidate (q1_q17_dr25_koi)',
#        'Kepler Project Candidate (q1_q8_koi)',
#        'Kepler Project Candidate (q1_q16_koi)',
#        'Kepler Project Candidate (q1_q17_dr25_sup_koi)',
#        'Kepler Project Candidate (q1_q17_dr24_koi)',
#        'Kepler Project Candidate (q1_q12_koi)'], dtype=object)

# %%
planets_df.isnull()
# Out:
#        pl_name  hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0        False     False         False    False    False            False
# 1        False     False         False    False    False            False
# 2        False     False         False    False    False            False
# 3        False     False         False    False    False            False
# 4        False     False         False    False    False            False
# ...        ...       ...           ...      ...      ...              ...
# 32052    False     False         False    False    False            False
# 32053    False     False         False    False    False            False
# 32054    False     False         False    False    False            False
# 32055    False     False         False    False    False            False
# 32056    False     False         False    False    False            False
#
#        disc_year  disc_facility  soltype  pl_controv_flag  ...  sy_vmagerr2  \
# ...

# %%
null_orbper = planets_df.pl_orbper.isnull()
null_orbper
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 32052    False
# 32053    False
# 32054    False
# 32055     True
# 32056    False
# Name: pl_orbper, Length: 32057, dtype: bool
