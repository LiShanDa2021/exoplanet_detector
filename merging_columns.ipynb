# %%
import pandas as pd
import os

# %%
file = pd.read_csv("kepler_data.csv")
file2 = pd.read_csv("composite_cleaned.csv")

planets_df = pd.DataFrame(file)
confirmed_planets_df = pd.DataFrame(file2)
planets_df
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560  10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562  10155286  K07988.01           NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0         1.000              0              0              0              0
# 1         0.969              0              0              0              0
# 2         0.000              0              0              0              0
# 3         0.000              0              1              0              0
# 4         1.000              0              0              0              0
# ...         ...            ...            ...            ...            ...
# 9559      0.000              0              1              1              0
# 9560      0.497              0              0              0              0
# 9561      0.021              0              0              1              0
# 9562      0.092              0              0              0              0
# 9563      0.000              0              0              1              1
#
#       ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0     ...           -81.0      4.467           0.064          -0.096
# 1     ...           -81.0      4.467           0.064          -0.096
# 2     ...          -176.0      4.544           0.044          -0.176
# 3     ...          -174.0      4.564           0.053          -0.168
# 4     ...          -211.0      4.438           0.070          -0.210
# ...   ...             ...        ...             ...             ...
# 9559  ...          -166.0      4.529           0.035          -0.196
# 9560  ...          -220.0      4.444           0.056          -0.224
# 9561  ...          -236.0      4.447           0.056          -0.224
# 9562  ...          -128.0      2.992           0.030          -0.027
# 9563  ...          -225.0      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 1        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 2        0.868          0.233         -0.078  297.00482  48.134129      15.436
# 3        0.791          0.201         -0.067  285.53461  48.285210      15.597
# 4        1.046          0.334         -0.133  288.75488  48.226200      15.509
# ...        ...            ...            ...        ...        ...         ...
# 9559     0.903          0.237         -0.079  297.18875  47.093819      14.082
# 9560     1.031          0.341         -0.114  286.50937  47.163219      14.757
# 9561     1.041          0.341         -0.114  294.16489  47.176281      15.385
# 9562     7.824          0.223         -1.896  296.76288  47.145142      10.998
# 9563     1.193          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 49 columns]

# %%
planets_df.columns
# Out:
# Index(['kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
len(planets_df.columns)
# Out:
# 49

# %%
# clean planet columns in excel before proceeding

# %%
#read in csv of cleaned column names
planet_column_names = pd.read_csv("planet_columns.csv")
planet_column_names = planet_column_names.df_columns
planet_column_names=planet_column_names.to_list()
planet_column_names
# Out:
# ['KepID',
#  'KOI_Name',
#  'Kepler_Name',
#  'Exoplanet_Archive_Disposition',
#  'Disposition_Using_Kepler_Data',
#  'Disposition_Score',
#  'Not_Transit-Like_False_Positive_Flag',
#  'Stellar_Eclipse_False_Positive_Flag',
#  'Centroid_Offset_False_Positive_Flag',
#  'Ephemeris_Match_Indicates_Contamination_False_Positive_Flag',
#  'Orbital_Period_[days]',
#  'Orbital_Period_Upper_Unc._[days]',
#  'Orbital_Period_Lower_Unc._[days]',
#  'Transit_Epoch_[BKJD]',
#  'Transit_Epoch_Upper_Unc._[BKJD]',
#  'Transit_Epoch_Lower_Unc._[BKJD]',
#  'Impact_Parameter',
#  'Impact_Parameter_Upper_Unc.',
#  'Impact_Parameter_Lower_Unc.',
#  'Transit_Duration_[hrs]',
#  'Transit_Duration_Upper_Unc._[hrs]',
#  'Transit_Duration_Lower_Unc._[hrs]',
#  'Transit_Depth_[ppm]',
#  'Transit_Depth_Upper_Unc._[ppm]',
#  'Transit_Depth_Lower_Unc._[ppm]',
#  'Planetary_Radius_[Earth_radii]',
#  'Planetary_Radius_Upper_Unc._[Earth_radii]',
#  'Planetary_Radius_Lower_Unc._[Earth_radii]',
#  'Equilibrium_Temperature_[K]',
#  'Equilibrium_Temperature_Upper_Unc._[K]',
#  'Equilibrium_Temperature_Lower_Unc._[K]',
#  'Insolation_Flux_[Earth_flux]',
#  'Insolation_Flux_Upper_Unc._[Earth_flux]',
#  'Insolation_Flux_Lower_Unc._[Earth_flux]',
#  'Transit_Signal-to-Noise',
#  'TCE_Planet_Number',
#  'TCE_Delivery',
#  'Stellar_Effective_Temperature_[K]',
#  'Stellar_Effective_Temperature_Upper_Unc._[K]',
#  'Stellar_Effective_Temperature_Lower_Unc._[K]',
#  'Stellar_Surface_Gravity_[log10(cm/s**2)]',
#  'Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]',
#  'Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]',
#  'Stellar_Radius_[Solar_radii]',
#  'Stellar_Radius_Upper_Unc._[Solar_radii]',
#  'Stellar_Radius_Lower_Unc._[Solar_radii]',
#  'RA_[decimal_degrees]',
#  'Dec_[decimal_degrees]',
#  'Kepler-band_[mag]']

# %%
#replace df column names with more legible columns
planets_df.columns = planet_column_names

# %%
planets_df
# Out:
#          KepID   KOI_Name   Kepler_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01  Kepler-227 b                     CONFIRMED
# 1     10797460  K00752.02  Kepler-227 c                     CONFIRMED
# 2     10811496  K00753.01           NaN                     CANDIDATE
# 3     10848459  K00754.01           NaN                FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b                     CONFIRMED
# ...        ...        ...           ...                           ...
# 9559  10090151  K07985.01           NaN                FALSE POSITIVE
# 9560  10128825  K07986.01           NaN                     CANDIDATE
# 9561  10147276  K07987.01           NaN                FALSE POSITIVE
# 9562  10155286  K07988.01           NaN                     CANDIDATE
# 9563  10156110  K07989.01           NaN                FALSE POSITIVE
#
#      Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                        CANDIDATE              1.000
# 1                        CANDIDATE              0.969
# 2                        CANDIDATE              0.000
# 3                   FALSE POSITIVE              0.000
# 4                        CANDIDATE              1.000
# ...                            ...                ...
# 9559                FALSE POSITIVE              0.000
# 9560                     CANDIDATE              0.497
# 9561                FALSE POSITIVE              0.021
# 9562                     CANDIDATE              0.092
# 9563                FALSE POSITIVE              0.000
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 9559                                     0
# 9560                                     0
# 9561                                     0
# 9562                                     0
# 9563                                     0
#
#       Stellar_Eclipse_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    0
# 9562                                    0
# 9563                                    0
#
#       Centroid_Offset_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    1
# 9562                                    0
# 9563                                    1
#
#       Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  ...  \
# 0                                                     0            ...
# 1                                                     0            ...
# 2                                                     0            ...
# 3                                                     0            ...
# 4                                                     0            ...
# ...                                                 ...            ...
# 9559                                                  0            ...
# 9560                                                  0            ...
# 9561                                                  0            ...
# 9562                                                  0            ...
# 9563                                                  1            ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 2                                           -176.0
# 3                                           -174.0
# 4                                           -211.0
# ...                                            ...
# 9559                                        -166.0
# 9560                                        -220.0
# 9561                                        -236.0
# 9562                                        -128.0
# 9563                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 49 columns]

# %%
#find out the number of solution types
planets_df.Exoplanet_Archive_Disposition.unique()
# Out:
# array(['CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE'], dtype=object)

# %%
# save the kepler names for later maybe
kep_names = planets_df.Kepler_Name
kep_names
# Out:
# 0       Kepler-227 b
# 1       Kepler-227 c
# 2                NaN
# 3                NaN
# 4       Kepler-664 b
#             ...
# 9559             NaN
# 9560             NaN
# 9561             NaN
# 9562             NaN
# 9563             NaN
# Name: Kepler_Name, Length: 9564, dtype: object

# %%
# should we drop the disposition using kepler since it's kind of redundant?

# %%
planets_df.isna()
# Out:
#       KepID  KOI_Name  Kepler_Name  Exoplanet_Archive_Disposition  \
# 0     False     False        False                          False
# 1     False     False        False                          False
# 2     False     False         True                          False
# 3     False     False         True                          False
# 4     False     False        False                          False
# ...     ...       ...          ...                            ...
# 9559  False     False         True                          False
# 9560  False     False         True                          False
# 9561  False     False         True                          False
# 9562  False     False         True                          False
# 9563  False     False         True                          False
#
#       Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                             False              False
# 1                             False              False
# 2                             False              False
# 3                             False              False
# 4                             False              False
# ...                             ...                ...
# 9559                          False              False
# 9560                          False              False
# 9561                          False              False
# 9562                          False              False
# 9563                          False              False
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 9559                                 False
# 9560                                 False
# 9561                                 False
# 9562                                 False
# 9563                                 False
#
#       Stellar_Eclipse_False_Positive_Flag  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 9559                                False
# 9560                                False
# 9561                                False
# 9562                                False
# 9563                                False
#
#       Centroid_Offset_False_Positive_Flag  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 9559                                False
# 9560                                False
# 9561                                False
# 9562                                False
# 9563                                False
#
#       Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  ...  \
# 0                                                 False            ...
# 1                                                 False            ...
# 2                                                 False            ...
# 3                                                 False            ...
# 4                                                 False            ...
# ...                                                 ...            ...
# 9559                                              False            ...
# 9560                                              False            ...
# 9561                                              False            ...
# 9562                                              False            ...
# 9563                                              False            ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 9559                                         False
# 9560                                         False
# 9561                                         False
# 9562                                         False
# 9563                                         False
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 9559                                     False
# 9560                                     False
# 9561                                     False
# 9562                                     False
# 9563                                     False
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9559                                              False
# 9560                                              False
# 9561                                              False
# 9562                                              False
# 9563                                              False
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9559                                              False
# 9560                                              False
# 9561                                              False
# 9562                                              False
# 9563                                              False
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            False                                    False
# 1                            False                                    False
# 2                            False                                    False
# 3                            False                                    False
# 4                            False                                    False
# ...                            ...                                      ...
# 9559                         False                                    False
# 9560                         False                                    False
# 9561                         False                                    False
# 9562                         False                                    False
# 9563                         False                                    False
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                       False                 False
# 1                                       False                 False
# 2                                       False                 False
# 3                                       False                 False
# 4                                       False                 False
# ...                                       ...                   ...
# 9559                                    False                 False
# 9560                                    False                 False
# 9561                                    False                 False
# 9562                                    False                 False
# 9563                                    False                 False
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                     False              False
# 1                     False              False
# 2                     False              False
# 3                     False              False
# 4                     False              False
# ...                     ...                ...
# 9559                  False              False
# 9560                  False              False
# 9561                  False              False
# 9562                  False              False
# 9563                  False              False
#
# [9564 rows x 49 columns]

# %%
# need to drop all columns that presuppose object is a planet
# as well as columns with too many NaNs

# %%
kepler_name_planets_df = planets_df.rename(columns= {"Kepler_Name": "Planet_Name" })
kepler_name_planets_df
# Out:
#          KepID   KOI_Name   Planet_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01  Kepler-227 b                     CONFIRMED
# 1     10797460  K00752.02  Kepler-227 c                     CONFIRMED
# 2     10811496  K00753.01           NaN                     CANDIDATE
# 3     10848459  K00754.01           NaN                FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b                     CONFIRMED
# ...        ...        ...           ...                           ...
# 9559  10090151  K07985.01           NaN                FALSE POSITIVE
# 9560  10128825  K07986.01           NaN                     CANDIDATE
# 9561  10147276  K07987.01           NaN                FALSE POSITIVE
# 9562  10155286  K07988.01           NaN                     CANDIDATE
# 9563  10156110  K07989.01           NaN                FALSE POSITIVE
#
#      Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                        CANDIDATE              1.000
# 1                        CANDIDATE              0.969
# 2                        CANDIDATE              0.000
# 3                   FALSE POSITIVE              0.000
# 4                        CANDIDATE              1.000
# ...                            ...                ...
# 9559                FALSE POSITIVE              0.000
# 9560                     CANDIDATE              0.497
# 9561                FALSE POSITIVE              0.021
# 9562                     CANDIDATE              0.092
# 9563                FALSE POSITIVE              0.000
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 9559                                     0
# 9560                                     0
# 9561                                     0
# 9562                                     0
# 9563                                     0
#
#       Stellar_Eclipse_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    0
# 9562                                    0
# 9563                                    0
#
#       Centroid_Offset_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    1
# 9562                                    0
# 9563                                    1
#
#       Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  ...  \
# 0                                                     0            ...
# 1                                                     0            ...
# 2                                                     0            ...
# 3                                                     0            ...
# 4                                                     0            ...
# ...                                                 ...            ...
# 9559                                                  0            ...
# 9560                                                  0            ...
# 9561                                                  0            ...
# 9562                                                  0            ...
# 9563                                                  1            ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 2                                           -176.0
# 3                                           -174.0
# 4                                           -211.0
# ...                                            ...
# 9559                                        -166.0
# 9560                                        -220.0
# 9561                                        -236.0
# 9562                                        -128.0
# 9563                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 49 columns]

# %%
kepler_name_planets_df = kepler_name_planets_df.dropna(subset = ["Planet_Name"])
kepler_name_planets_df
# Out:
#          KepID   KOI_Name    Planet_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01   Kepler-227 b                     CONFIRMED
# 1     10797460  K00752.02   Kepler-227 c                     CONFIRMED
# 4     10854555  K00755.01   Kepler-664 b                     CONFIRMED
# 5     10872983  K00756.01   Kepler-228 d                     CONFIRMED
# 6     10872983  K00756.02   Kepler-228 c                     CONFIRMED
# ...        ...        ...            ...                           ...
# 8057   8540376  K07892.01   Kepler-457 d                     CONFIRMED
# 8817   7350067  K06863.01  Kepler-1646 b                     CONFIRMED
# 8956   9730163  K02704.03   Kepler-445 d                     CONFIRMED
# 9014   8311864  K07016.01   Kepler-452 b                     CONFIRMED
# 9083   7935997  K05447.02  Kepler-1629 b                     CONFIRMED
#
#      Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                        CANDIDATE              1.000
# 1                        CANDIDATE              0.969
# 4                        CANDIDATE              1.000
# 5                        CANDIDATE              1.000
# 6                        CANDIDATE              1.000
# ...                            ...                ...
# 8057                     CANDIDATE              0.994
# 8817                     CANDIDATE              1.000
# 8956                     CANDIDATE                NaN
# 9014                     CANDIDATE              0.771
# 9083                     CANDIDATE              0.000
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                        0
# 1                                        0
# 4                                        0
# 5                                        0
# 6                                        0
# ...                                    ...
# 8057                                     0
# 8817                                     0
# 8956                                     0
# 9014                                     0
# 9083                                     0
#
#       Stellar_Eclipse_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 4                                       0
# 5                                       0
# 6                                       0
# ...                                   ...
# 8057                                    0
# 8817                                    0
# 8956                                    0
# 9014                                    0
# 9083                                    0
#
#       Centroid_Offset_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 4                                       0
# 5                                       0
# 6                                       0
# ...                                   ...
# 8057                                    0
# 8817                                    0
# 8956                                    0
# 9014                                    0
# 9083                                    0
#
#       Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  ...  \
# 0                                                     0            ...
# 1                                                     0            ...
# 4                                                     0            ...
# 5                                                     0            ...
# 6                                                     0            ...
# ...                                                 ...            ...
# 8057                                                  0            ...
# 8817                                                  0            ...
# 8956                                                  0            ...
# 9014                                                  0            ...
# 9083                                                  0            ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 4                                           -211.0
# 5                                           -232.0
# 6                                           -232.0
# ...                                            ...
# 8057                                        -250.0
# 8817                                         -25.0
# 8956                                         -58.0
# 9014                                        -150.0
# 9083                                         -85.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 4                                        4.438
# 5                                        4.486
# 6                                        4.486
# ...                                        ...
# 8057                                     4.311
# 8817                                     5.097
# 8956                                     5.113
# 9014                                     4.580
# 9083                                     4.541
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 4                                                 0.070
# 5                                                 0.054
# 6                                                 0.054
# ...                                                 ...
# 8057                                              0.108
# 8817                                              0.055
# 8956                                              0.140
# 9014                                              0.034
# 9083                                              0.013
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 4                                                -0.210
# 5                                                -0.229
# 6                                                -0.229
# ...                                                 ...
# 8057                                             -0.201
# 8817                                             -0.050
# 8956                                             -0.140
# 9014                                             -0.127
# 9083                                             -0.117
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 4                            1.046                                    0.334
# 5                            0.972                                    0.315
# 6                            0.972                                    0.315
# ...                            ...                                      ...
# 8057                         1.242                                    0.380
# 8817                         0.193                                    0.034
# 8956                         0.189                                    0.125
# 9014                         0.798                                    0.150
# 9083                         0.893                                    0.125
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 4                                      -0.133             288.75488
# 5                                      -0.105             296.28613
# 6                                      -0.105             296.28613
# ...                                       ...                   ...
# 8057                                   -0.205             282.37753
# 8817                                   -0.025             287.52640
# 8956                                   -0.054             298.73611
# 9014                                   -0.075             296.00369
# 9083                                   -0.033             280.20660
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 4                 48.226200             15.509
# 5                 48.224670             15.714
# 6                 48.224670             15.714
# ...                     ...                ...
# 8057              44.694592             14.294
# 8817              42.912899             15.737
# 8956              46.498634             17.475
# 9014              44.277561             13.426
# 9083              43.774288             12.750
#
# [2668 rows x 49 columns]

# %%
kepler_name_planets_df = kepler_name_planets_df.set_index("Planet_Name")
kepler_name_planets_df
# Out:
#                   KepID   KOI_Name Exoplanet_Archive_Disposition  \
# Planet_Name
# Kepler-227 b   10797460  K00752.01                     CONFIRMED
# Kepler-227 c   10797460  K00752.02                     CONFIRMED
# Kepler-664 b   10854555  K00755.01                     CONFIRMED
# Kepler-228 d   10872983  K00756.01                     CONFIRMED
# Kepler-228 c   10872983  K00756.02                     CONFIRMED
# ...                 ...        ...                           ...
# Kepler-457 d    8540376  K07892.01                     CONFIRMED
# Kepler-1646 b   7350067  K06863.01                     CONFIRMED
# Kepler-445 d    9730163  K02704.03                     CONFIRMED
# Kepler-452 b    8311864  K07016.01                     CONFIRMED
# Kepler-1629 b   7935997  K05447.02                     CONFIRMED
#
#               Disposition_Using_Kepler_Data  Disposition_Score  \
# Planet_Name
# Kepler-227 b                      CANDIDATE              1.000
# Kepler-227 c                      CANDIDATE              0.969
# Kepler-664 b                      CANDIDATE              1.000
# Kepler-228 d                      CANDIDATE              1.000
# Kepler-228 c                      CANDIDATE              1.000
# ...                                     ...                ...
# Kepler-457 d                      CANDIDATE              0.994
# Kepler-1646 b                     CANDIDATE              1.000
# Kepler-445 d                      CANDIDATE                NaN
# Kepler-452 b                      CANDIDATE              0.771
# Kepler-1629 b                     CANDIDATE              0.000
#
#                Not_Transit-Like_False_Positive_Flag  \
# Planet_Name
# Kepler-227 b                                      0
# Kepler-227 c                                      0
# Kepler-664 b                                      0
# Kepler-228 d                                      0
# Kepler-228 c                                      0
# ...                                             ...
# Kepler-457 d                                      0
# Kepler-1646 b                                     0
# Kepler-445 d                                      0
# Kepler-452 b                                      0
# Kepler-1629 b                                     0
#
#                Stellar_Eclipse_False_Positive_Flag  \
# Planet_Name
# Kepler-227 b                                     0
# Kepler-227 c                                     0
# Kepler-664 b                                     0
# Kepler-228 d                                     0
# Kepler-228 c                                     0
# ...                                            ...
# Kepler-457 d                                     0
# Kepler-1646 b                                    0
# Kepler-445 d                                     0
# Kepler-452 b                                     0
# Kepler-1629 b                                    0
#
#                Centroid_Offset_False_Positive_Flag  \
# Planet_Name
# Kepler-227 b                                     0
# Kepler-227 c                                     0
# Kepler-664 b                                     0
# Kepler-228 d                                     0
# Kepler-228 c                                     0
# ...                                            ...
# Kepler-457 d                                     0
# Kepler-1646 b                                    0
# Kepler-445 d                                     0
# Kepler-452 b                                     0
# Kepler-1629 b                                    0
#
#                Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  \
# Planet_Name
# Kepler-227 b                                                   0
# Kepler-227 c                                                   0
# Kepler-664 b                                                   0
# Kepler-228 d                                                   0
# Kepler-228 c                                                   0
# ...                                                          ...
# Kepler-457 d                                                   0
# Kepler-1646 b                                                  0
# Kepler-445 d                                                   0
# Kepler-452 b                                                   0
# Kepler-1629 b                                                  0
#
#                Orbital_Period_[days]  ...  \
# Planet_Name                           ...
# Kepler-227 b                9.488036  ...
# Kepler-227 c               54.418383  ...
# Kepler-664 b                2.525592  ...
# Kepler-228 d               11.094321  ...
# Kepler-228 c                4.134435  ...
# ...                              ...  ...
# Kepler-457 d               10.692115  ...
# Kepler-1646 b               4.485592  ...
# Kepler-445 d                8.152759  ...
# Kepler-452 b              384.847556  ...
# Kepler-1629 b               3.875943  ...
#
#                Stellar_Effective_Temperature_Lower_Unc._[K]  \
# Planet_Name
# Kepler-227 b                                          -81.0
# Kepler-227 c                                          -81.0
# Kepler-664 b                                         -211.0
# Kepler-228 d                                         -232.0
# Kepler-228 c                                         -232.0
# ...                                                     ...
# Kepler-457 d                                         -250.0
# Kepler-1646 b                                         -25.0
# Kepler-445 d                                          -58.0
# Kepler-452 b                                         -150.0
# Kepler-1629 b                                         -85.0
#
#                Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# Planet_Name
# Kepler-227 b                                      4.467
# Kepler-227 c                                      4.467
# Kepler-664 b                                      4.438
# Kepler-228 d                                      4.486
# Kepler-228 c                                      4.486
# ...                                                 ...
# Kepler-457 d                                      4.311
# Kepler-1646 b                                     5.097
# Kepler-445 d                                      5.113
# Kepler-452 b                                      4.580
# Kepler-1629 b                                     4.541
#
#                Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# Planet_Name
# Kepler-227 b                                               0.064
# Kepler-227 c                                               0.064
# Kepler-664 b                                               0.070
# Kepler-228 d                                               0.054
# Kepler-228 c                                               0.054
# ...                                                          ...
# Kepler-457 d                                               0.108
# Kepler-1646 b                                              0.055
# Kepler-445 d                                               0.140
# Kepler-452 b                                               0.034
# Kepler-1629 b                                              0.013
#
#                Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# Planet_Name
# Kepler-227 b                                              -0.096
# Kepler-227 c                                              -0.096
# Kepler-664 b                                              -0.210
# Kepler-228 d                                              -0.229
# Kepler-228 c                                              -0.229
# ...                                                          ...
# Kepler-457 d                                              -0.201
# Kepler-1646 b                                             -0.050
# Kepler-445 d                                              -0.140
# Kepler-452 b                                              -0.127
# Kepler-1629 b                                             -0.117
#
#                Stellar_Radius_[Solar_radii]  \
# Planet_Name
# Kepler-227 b                          0.927
# Kepler-227 c                          0.927
# Kepler-664 b                          1.046
# Kepler-228 d                          0.972
# Kepler-228 c                          0.972
# ...                                     ...
# Kepler-457 d                          1.242
# Kepler-1646 b                         0.193
# Kepler-445 d                          0.189
# Kepler-452 b                          0.798
# Kepler-1629 b                         0.893
#
#                Stellar_Radius_Upper_Unc._[Solar_radii]  \
# Planet_Name
# Kepler-227 b                                     0.105
# Kepler-227 c                                     0.105
# Kepler-664 b                                     0.334
# Kepler-228 d                                     0.315
# Kepler-228 c                                     0.315
# ...                                                ...
# Kepler-457 d                                     0.380
# Kepler-1646 b                                    0.034
# Kepler-445 d                                     0.125
# Kepler-452 b                                     0.150
# Kepler-1629 b                                    0.125
#
#                Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# Planet_Name
# Kepler-227 b                                    -0.061             291.93423
# Kepler-227 c                                    -0.061             291.93423
# Kepler-664 b                                    -0.133             288.75488
# Kepler-228 d                                    -0.105             296.28613
# Kepler-228 c                                    -0.105             296.28613
# ...                                                ...                   ...
# Kepler-457 d                                    -0.205             282.37753
# Kepler-1646 b                                   -0.025             287.52640
# Kepler-445 d                                    -0.054             298.73611
# Kepler-452 b                                    -0.075             296.00369
# Kepler-1629 b                                   -0.033             280.20660
#
#                Dec_[decimal_degrees]  Kepler-band_[mag]
# Planet_Name
# Kepler-227 b               48.141651             15.347
# Kepler-227 c               48.141651             15.347
# Kepler-664 b               48.226200             15.509
# Kepler-228 d               48.224670             15.714
# Kepler-228 c               48.224670             15.714
# ...                              ...                ...
# Kepler-457 d               44.694592             14.294
# Kepler-1646 b              42.912899             15.737
# Kepler-445 d               46.498634             17.475
# Kepler-452 b               44.277561             13.426
# Kepler-1629 b              43.774288             12.750
#
# [2668 rows x 48 columns]

# %%
planets_df.Kepler_Name.isna().sum()
# Out:
# 6896

# %%
planets_df.Kepler_Name.isna().sum()/len(planets_df.Kepler_Name)
# Out:
# 0.7210372229192806

# %%
# identify columns that are more than 20% empty
empty_columns = []
for column in planets_df:
    column_name=column
    if (planets_df[column].isna().sum()/len(planets_df[column]) > 0.20):
        empty_columns.append(column_name)

empty_columns
# Out:
# ['Kepler_Name',
#  'Equilibrium_Temperature_Upper_Unc._[K]',
#  'Equilibrium_Temperature_Lower_Unc._[K]']

# %%
planets_df=planets_df.drop(columns=empty_columns, axis=1)

# %%
planets_df
# Out:
#          KepID   KOI_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01                     CONFIRMED
# 1     10797460  K00752.02                     CONFIRMED
# 2     10811496  K00753.01                     CANDIDATE
# 3     10848459  K00754.01                FALSE POSITIVE
# 4     10854555  K00755.01                     CONFIRMED
# ...        ...        ...                           ...
# 9559  10090151  K07985.01                FALSE POSITIVE
# 9560  10128825  K07986.01                     CANDIDATE
# 9561  10147276  K07987.01                FALSE POSITIVE
# 9562  10155286  K07988.01                     CANDIDATE
# 9563  10156110  K07989.01                FALSE POSITIVE
#
#      Disposition_Using_Kepler_Data  Disposition_Score  \
# 0                        CANDIDATE              1.000
# 1                        CANDIDATE              0.969
# 2                        CANDIDATE              0.000
# 3                   FALSE POSITIVE              0.000
# 4                        CANDIDATE              1.000
# ...                            ...                ...
# 9559                FALSE POSITIVE              0.000
# 9560                     CANDIDATE              0.497
# 9561                FALSE POSITIVE              0.021
# 9562                     CANDIDATE              0.092
# 9563                FALSE POSITIVE              0.000
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 9559                                     0
# 9560                                     0
# 9561                                     0
# 9562                                     0
# 9563                                     0
#
#       Stellar_Eclipse_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    0
# 9562                                    0
# 9563                                    0
#
#       Centroid_Offset_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    1
# 9562                                    0
# 9563                                    1
#
#       Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 9559                                                  0
# 9560                                                  0
# 9561                                                  0
# 9562                                                  0
# 9563                                                  1
#
#       Orbital_Period_[days]  ...  \
# 0                  9.488036  ...
# 1                 54.418383  ...
# 2                 19.899140  ...
# 3                  1.736952  ...
# 4                  2.525592  ...
# ...                     ...  ...
# 9559               0.527699  ...
# 9560               1.739849  ...
# 9561               0.681402  ...
# 9562             333.486169  ...
# 9563               4.856035  ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 2                                           -176.0
# 3                                           -174.0
# 4                                           -211.0
# ...                                            ...
# 9559                                        -166.0
# 9560                                        -220.0
# 9561                                        -236.0
# 9562                                        -128.0
# 9563                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 46 columns]

# %%
# drop disposition using kepler data and disposition score -- because that's actually what we are trying to create
# Exoplanet_Archive_Disposition will ultimately be our target
planets_df=planets_df.drop(columns=['Disposition_Using_Kepler_Data','Disposition_Score'], axis=1)
planets_df
# Out:
#          KepID   KOI_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01                     CONFIRMED
# 1     10797460  K00752.02                     CONFIRMED
# 2     10811496  K00753.01                     CANDIDATE
# 3     10848459  K00754.01                FALSE POSITIVE
# 4     10854555  K00755.01                     CONFIRMED
# ...        ...        ...                           ...
# 9559  10090151  K07985.01                FALSE POSITIVE
# 9560  10128825  K07986.01                     CANDIDATE
# 9561  10147276  K07987.01                FALSE POSITIVE
# 9562  10155286  K07988.01                     CANDIDATE
# 9563  10156110  K07989.01                FALSE POSITIVE
#
#       Not_Transit-Like_False_Positive_Flag  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 9559                                     0
# 9560                                     0
# 9561                                     0
# 9562                                     0
# 9563                                     0
#
#       Stellar_Eclipse_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    0
# 9562                                    0
# 9563                                    0
#
#       Centroid_Offset_False_Positive_Flag  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 9559                                    1
# 9560                                    0
# 9561                                    1
# 9562                                    0
# 9563                                    1
#
#       Ephemeris_Match_Indicates_Contamination_False_Positive_Flag  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 9559                                                  0
# 9560                                                  0
# 9561                                                  0
# 9562                                                  0
# 9563                                                  1
#
#       Orbital_Period_[days]  Orbital_Period_Upper_Unc._[days]  \
# 0                  9.488036                      2.775000e-05
# 1                 54.418383                      2.479000e-04
# 2                 19.899140                      1.494000e-05
# 3                  1.736952                      2.630000e-07
# 4                  2.525592                      3.761000e-06
# ...                     ...                               ...
# 9559               0.527699                      1.160000e-07
# 9560               1.739849                      1.780000e-05
# 9561               0.681402                      2.434000e-06
# 9562             333.486169                      4.235000e-03
# 9563               4.856035                      6.356000e-05
#
#       Orbital_Period_Lower_Unc._[days]  ...  \
# 0                        -2.775000e-05  ...
# 1                        -2.479000e-04  ...
# 2                        -1.494000e-05  ...
# 3                        -2.630000e-07  ...
# 4                        -3.761000e-06  ...
# ...                                ...  ...
# 9559                     -1.160000e-07  ...
# 9560                     -1.780000e-05  ...
# 9561                     -2.434000e-06  ...
# 9562                     -4.235000e-03  ...
# 9563                     -6.356000e-05  ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 2                                           -176.0
# 3                                           -174.0
# 4                                           -211.0
# ...                                            ...
# 9559                                        -166.0
# 9560                                        -220.0
# 9561                                        -236.0
# 9562                                        -128.0
# 9563                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 44 columns]

# %%
planets_df['Not_Transit-Like_False_Positive_Flag'].unique()
# Out:
# array([  0,   1, 465], dtype=int64)

# %%
# drop False_Positive_Flag columns because they are basically giving us the answer we are trying to calculate
planets_df=planets_df.drop(columns=['Not_Transit-Like_False_Positive_Flag','Stellar_Eclipse_False_Positive_Flag', 'Centroid_Offset_False_Positive_Flag', 'Ephemeris_Match_Indicates_Contamination_False_Positive_Flag'], axis=1)

# %%
planets_df
# Out:
#          KepID   KOI_Name Exoplanet_Archive_Disposition  \
# 0     10797460  K00752.01                     CONFIRMED
# 1     10797460  K00752.02                     CONFIRMED
# 2     10811496  K00753.01                     CANDIDATE
# 3     10848459  K00754.01                FALSE POSITIVE
# 4     10854555  K00755.01                     CONFIRMED
# ...        ...        ...                           ...
# 9559  10090151  K07985.01                FALSE POSITIVE
# 9560  10128825  K07986.01                     CANDIDATE
# 9561  10147276  K07987.01                FALSE POSITIVE
# 9562  10155286  K07988.01                     CANDIDATE
# 9563  10156110  K07989.01                FALSE POSITIVE
#
#       Orbital_Period_[days]  Orbital_Period_Upper_Unc._[days]  \
# 0                  9.488036                      2.775000e-05
# 1                 54.418383                      2.479000e-04
# 2                 19.899140                      1.494000e-05
# 3                  1.736952                      2.630000e-07
# 4                  2.525592                      3.761000e-06
# ...                     ...                               ...
# 9559               0.527699                      1.160000e-07
# 9560               1.739849                      1.780000e-05
# 9561               0.681402                      2.434000e-06
# 9562             333.486169                      4.235000e-03
# 9563               4.856035                      6.356000e-05
#
#       Orbital_Period_Lower_Unc._[days]  Transit_Epoch_[BKJD]  \
# 0                        -2.775000e-05            170.538750
# 1                        -2.479000e-04            162.513840
# 2                        -1.494000e-05            175.850252
# 3                        -2.630000e-07            170.307565
# 4                        -3.761000e-06            171.595550
# ...                                ...                   ...
# 9559                     -1.160000e-07            131.705093
# 9560                     -1.780000e-05            133.001270
# 9561                     -2.434000e-06            132.181750
# 9562                     -4.235000e-03            153.615010
# 9563                     -6.356000e-05            135.993300
#
#       Transit_Epoch_Upper_Unc._[BKJD]  Transit_Epoch_Lower_Unc._[BKJD]  \
# 0                            0.002160                        -0.002160
# 1                            0.003520                        -0.003520
# 2                            0.000581                        -0.000581
# 3                            0.000115                        -0.000115
# 4                            0.001130                        -0.001130
# ...                               ...                              ...
# 9559                         0.000170                        -0.000170
# 9560                         0.007690                        -0.007690
# 9561                         0.002850                        -0.002850
# 9562                         0.005070                        -0.005070
# 9563                         0.010800                        -0.010800
#
#       Impact_Parameter  ...  Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                0.146  ...                                         -81.0
# 1                0.586  ...                                         -81.0
# 2                0.969  ...                                        -176.0
# 3                1.276  ...                                        -174.0
# 4                0.701  ...                                        -211.0
# ...                ...  ...                                           ...
# 9559             1.252  ...                                        -166.0
# 9560             0.043  ...                                        -220.0
# 9561             0.147  ...                                        -236.0
# 9562             0.214  ...                                        -128.0
# 9563             0.134  ...                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 40 columns]

# %%
# find out how many of each disposition there are in Exoplanet_Archive_Disposition
planets_df.Exoplanet_Archive_Disposition.value_counts()
# Out:
# FALSE POSITIVE    4840
# CONFIRMED         2666
# CANDIDATE         2058
# Name: Exoplanet_Archive_Disposition, dtype: int64

# %%
# find the biggest star 	Stellar_Radius_[Solar_radii]
planets_df['Stellar_Radius_[Solar_radii]'].sort_values(ascending=False)
# Out:
# 8453    229.908
# 4976    180.013
# 7917    162.725
# 5545    152.969
# 9229    151.184
#          ...
# 9348        NaN
# 9393        NaN
# 9406        NaN
# 9501        NaN
# 9517        NaN
# Name: Stellar_Radius_[Solar_radii], Length: 9564, dtype: float64

# %%
# find the smallest star 	Stellar_Radius_[Solar_radii]
planets_df['Stellar_Radius_[Solar_radii]'].sort_values(ascending=True)
# Out:
# 8530    0.109
# 3739    0.116
# 9222    0.116
# 2567    0.116
# 633     0.116
#         ...
# 9348      NaN
# 9393      NaN
# 9406      NaN
# 9501      NaN
# 9517      NaN
# Name: Stellar_Radius_[Solar_radii], Length: 9564, dtype: float64

# %%
planets_df.columns
# Out:
# Index(['KepID', 'KOI_Name', 'Exoplanet_Archive_Disposition',
#        'Orbital_Period_[days]', 'Orbital_Period_Upper_Unc._[days]',
#        'Orbital_Period_Lower_Unc._[days]', 'Transit_Epoch_[BKJD]',
#        'Transit_Epoch_Upper_Unc._[BKJD]', 'Transit_Epoch_Lower_Unc._[BKJD]',
#        'Impact_Parameter', 'Impact_Parameter_Upper_Unc.',
#        'Impact_Parameter_Lower_Unc.', 'Transit_Duration_[hrs]',
#        'Transit_Duration_Upper_Unc._[hrs]',
#        'Transit_Duration_Lower_Unc._[hrs]', 'Transit_Depth_[ppm]',
#        'Transit_Depth_Upper_Unc._[ppm]', 'Transit_Depth_Lower_Unc._[ppm]',
#        'Planetary_Radius_[Earth_radii]',
#        'Planetary_Radius_Upper_Unc._[Earth_radii]',
#        'Planetary_Radius_Lower_Unc._[Earth_radii]',
#        'Equilibrium_Temperature_[K]', 'Insolation_Flux_[Earth_flux]',
#        'Insolation_Flux_Upper_Unc._[Earth_flux]',
#        'Insolation_Flux_Lower_Unc._[Earth_flux]', 'Transit_Signal-to-Noise',
#        'TCE_Planet_Number', 'TCE_Delivery',
#        'Stellar_Effective_Temperature_[K]',
#        'Stellar_Effective_Temperature_Upper_Unc._[K]',
#        'Stellar_Effective_Temperature_Lower_Unc._[K]',
#        'Stellar_Surface_Gravity_[log10(cm/s**2)]',
#        'Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]',
#        'Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]',
#        'Stellar_Radius_[Solar_radii]',
#        'Stellar_Radius_Upper_Unc._[Solar_radii]',
#        'Stellar_Radius_Lower_Unc._[Solar_radii]', 'RA_[decimal_degrees]',
#        'Dec_[decimal_degrees]', 'Kepler-band_[mag]'],
#       dtype='object')

# %%
len(planets_df.columns)
# Out:
# 40

# %%
# find the biggest planet
planets_df['Planetary_Radius_[Earth_radii]'].sort_values(ascending=False)
# Out:
# 8893    200346.0
# 8747    161858.0
# 7151    109061.0
# 8529     64333.8
# 6336     46743.4
#           ...
# 9348         NaN
# 9393         NaN
# 9406         NaN
# 9501         NaN
# 9517         NaN
# Name: Planetary_Radius_[Earth_radii], Length: 9564, dtype: float64

# %%
len(planets_df['KepID'].unique())
# Out:
# 8214

# %%
len(planets_df['KOI_Name'].unique())
# Out:
# 9564

# %%
# drop KepID since it isn't unique and isn't predictive
planets_df=planets_df.drop(columns=['KepID'], axis=1)
planets_df
# Out:
#        KOI_Name Exoplanet_Archive_Disposition  Orbital_Period_[days]  \
# 0     K00752.01                     CONFIRMED               9.488036
# 1     K00752.02                     CONFIRMED              54.418383
# 2     K00753.01                     CANDIDATE              19.899140
# 3     K00754.01                FALSE POSITIVE               1.736952
# 4     K00755.01                     CONFIRMED               2.525592
# ...         ...                           ...                    ...
# 9559  K07985.01                FALSE POSITIVE               0.527699
# 9560  K07986.01                     CANDIDATE               1.739849
# 9561  K07987.01                FALSE POSITIVE               0.681402
# 9562  K07988.01                     CANDIDATE             333.486169
# 9563  K07989.01                FALSE POSITIVE               4.856035
#
#       Orbital_Period_Upper_Unc._[days]  Orbital_Period_Lower_Unc._[days]  \
# 0                         2.775000e-05                     -2.775000e-05
# 1                         2.479000e-04                     -2.479000e-04
# 2                         1.494000e-05                     -1.494000e-05
# 3                         2.630000e-07                     -2.630000e-07
# 4                         3.761000e-06                     -3.761000e-06
# ...                                ...                               ...
# 9559                      1.160000e-07                     -1.160000e-07
# 9560                      1.780000e-05                     -1.780000e-05
# 9561                      2.434000e-06                     -2.434000e-06
# 9562                      4.235000e-03                     -4.235000e-03
# 9563                      6.356000e-05                     -6.356000e-05
#
#       Transit_Epoch_[BKJD]  Transit_Epoch_Upper_Unc._[BKJD]  \
# 0               170.538750                         0.002160
# 1               162.513840                         0.003520
# 2               175.850252                         0.000581
# 3               170.307565                         0.000115
# 4               171.595550                         0.001130
# ...                    ...                              ...
# 9559            131.705093                         0.000170
# 9560            133.001270                         0.007690
# 9561            132.181750                         0.002850
# 9562            153.615010                         0.005070
# 9563            135.993300                         0.010800
#
#       Transit_Epoch_Lower_Unc._[BKJD]  Impact_Parameter  \
# 0                           -0.002160             0.146
# 1                           -0.003520             0.586
# 2                           -0.000581             0.969
# 3                           -0.000115             1.276
# 4                           -0.001130             0.701
# ...                               ...               ...
# 9559                        -0.000170             1.252
# 9560                        -0.007690             0.043
# 9561                        -0.002850             0.147
# 9562                        -0.005070             0.214
# 9563                        -0.010800             0.134
#
#       Impact_Parameter_Upper_Unc.  ...  \
# 0                           0.318  ...
# 1                           0.059  ...
# 2                           5.126  ...
# 3                           0.115  ...
# 4                           0.235  ...
# ...                           ...  ...
# 9559                        0.051  ...
# 9560                        0.423  ...
# 9561                        0.309  ...
# 9562                        0.255  ...
# 9563                        0.323  ...
#
#       Stellar_Effective_Temperature_Lower_Unc._[K]  \
# 0                                            -81.0
# 1                                            -81.0
# 2                                           -176.0
# 3                                           -174.0
# 4                                           -211.0
# ...                                            ...
# 9559                                        -166.0
# 9560                                        -220.0
# 9561                                        -236.0
# 9562                                        -128.0
# 9563                                        -225.0
#
#       Stellar_Surface_Gravity_[log10(cm/s**2)]  \
# 0                                        4.467
# 1                                        4.467
# 2                                        4.544
# 3                                        4.564
# 4                                        4.438
# ...                                        ...
# 9559                                     4.529
# 9560                                     4.444
# 9561                                     4.447
# 9562                                     2.992
# 9563                                     4.385
#
#       Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]  \
# 0                                                 0.064
# 1                                                 0.064
# 2                                                 0.044
# 3                                                 0.053
# 4                                                 0.070
# ...                                                 ...
# 9559                                              0.035
# 9560                                              0.056
# 9561                                              0.056
# 9562                                              0.030
# 9563                                              0.054
#
#       Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]  \
# 0                                                -0.096
# 1                                                -0.096
# 2                                                -0.176
# 3                                                -0.168
# 4                                                -0.210
# ...                                                 ...
# 9559                                             -0.196
# 9560                                             -0.224
# 9561                                             -0.224
# 9562                                             -0.027
# 9563                                             -0.216
#
#       Stellar_Radius_[Solar_radii]  Stellar_Radius_Upper_Unc._[Solar_radii]  \
# 0                            0.927                                    0.105
# 1                            0.927                                    0.105
# 2                            0.868                                    0.233
# 3                            0.791                                    0.201
# 4                            1.046                                    0.334
# ...                            ...                                      ...
# 9559                         0.903                                    0.237
# 9560                         1.031                                    0.341
# 9561                         1.041                                    0.341
# 9562                         7.824                                    0.223
# 9563                         1.193                                    0.410
#
#       Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# 0                                      -0.061             291.93423
# 1                                      -0.061             291.93423
# 2                                      -0.078             297.00482
# 3                                      -0.067             285.53461
# 4                                      -0.133             288.75488
# ...                                       ...                   ...
# 9559                                   -0.079             297.18875
# 9560                                   -0.114             286.50937
# 9561                                   -0.114             294.16489
# 9562                                   -1.896             296.76288
# 9563                                   -0.137             297.00977
#
#       Dec_[decimal_degrees]  Kepler-band_[mag]
# 0                 48.141651             15.347
# 1                 48.141651             15.347
# 2                 48.134129             15.436
# 3                 48.285210             15.597
# 4                 48.226200             15.509
# ...                     ...                ...
# 9559              47.093819             14.082
# 9560              47.163219             14.757
# 9561              47.176281             15.385
# 9562              47.145142             10.998
# 9563              47.121021             14.826
#
# [9564 rows x 39 columns]

# %%
new_planets_df=planets_df.
# Out:
#   File "C:\Users\KYLEBE~1\AppData\Local\Temp/ipykernel_5800/1845754778.py", line 1
#     new_planets_df=planets_df.
#                               ^
# SyntaxError: invalid syntax

# %%
new_planets_confirmed_df = new_planets_df.loc[new_planets_df["Exoplanet_Archive_Disposition"] == "CONFIRMED" ]
new_planets_confirmed_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KYLEBE~1\AppData\Local\Temp/ipykernel_5800/1878739630.py in <module>
# ----> 1 new_planets_confirmed_df = new_planets_df.loc[new_planets_df["Exoplanet_Archive_Disposition"] == "CONFIRMED" ]
#       2 new_planets_confirmed_df
#
# NameError: name 'new_planets_df' is not defined

# %%
new_planets_confirmed_df.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KYLEBE~1\AppData\Local\Temp/ipykernel_5800/3537084211.py in <module>
# ----> 1 new_planets_confirmed_df.nunique()
#
# NameError: name 'new_planets_confirmed_df' is not defined

# %%
confirmed_planets_df = confirmed_planets_df.loc[confirmed_planets_df["Discovery_Facility"] == "Kepler" ]
confirmed_planets_df
# Out:
#       Unnamed: 0                Planet_Name                Host_Name  \
# 17            17  2MASS J19383260+4603591 b  2MASS J19383260+4603591
# 1578        1578             KIC 10001893 b             KIC 10001893
# 1579        1579             KIC 10001893 c             KIC 10001893
# 1580        1580             KIC 10001893 d             KIC 10001893
# 1581        1581             KIC 10068024 b             KIC 10068024
# ...          ...                        ...                      ...
# 4324        4324               Kepler-997 b               Kepler-997
# 4325        4325               Kepler-998 b               Kepler-998
# 4326        4326               Kepler-999 b               Kepler-999
# 4488        4488                      PH1 b                      PH1
# 4489        4489                      PH2 b                      PH2
#
#       Number_of_Stars  Number_of_Planets               Discovery_Method  \
# 17                  2                  1      Eclipse Timing Variations
# 1578                1                  3  Orbital Brightness Modulation
# 1579                1                  3  Orbital Brightness Modulation
# 1580                1                  3  Orbital Brightness Modulation
# 1581                1                  1  Orbital Brightness Modulation
# ...               ...                ...                            ...
# 4324                1                  1                        Transit
# 4325                1                  1                        Transit
# 4326                1                  1                        Transit
# 4488                4                  1                        Transit
# 4489                1                  1                        Transit
#
#       Discovery_Year Discovery_Facility  Controversial_Flag  \
# 17              2015             Kepler                   0
# 1578            2014             Kepler                   1
# 1579            2014             Kepler                   1
# 1580            2014             Kepler                   1
# 1581            2021             Kepler                   0
# ...              ...                ...                 ...
# 4324            2016             Kepler                   0
# 4325            2016             Kepler                   0
# 4326            2016             Kepler                   0
# 4488            2012             Kepler                   0
# 4489            2013             Kepler                   0
#
#       Orbital_Period_[days]  ...  Distance_[pc]_Lower_Unc  \
# 17               416.000000  ...                  -6.3885
# 1578               0.219700  ...                -149.7000
# 1579               0.325280  ...                -149.7000
# 1580               0.811610  ...                -149.7000
# 1581               2.073549  ...                      NaN
# ...                     ...  ...                      ...
# 4324               2.707307  ...                  -5.5740
# 4325               5.653777  ...                 -15.1970
# 4326               5.991857  ...                  -7.9620
# 4488             138.317000  ...                      NaN
# 4489             282.525500  ...                  -3.5570
#
#       V_(Johnson)_Magnitude  V_(Johnson)_Magnitude_Upper_Unc  \
# 17                   12.651                            0.215
# 1578                 15.829                            0.150
# 1579                 15.829                            0.150
# 1580                 15.829                            0.150
# 1581                 13.144                            0.092
# ...                     ...                              ...
# 4324                 11.521                            0.038
# 4325                 14.463                            0.080
# 4326                 12.364                            0.069
# 4488                 13.841                            0.149
# 4489                 12.645                            0.046
#
#       V_(Johnson)_Magnitude_Lower_Unc  Ks_(2MASS)_Magnitude  \
# 17                             -0.215                12.955
# 1578                           -0.150                16.612
# 1579                           -0.150                16.612
# 1580                           -0.150                16.612
# 1581                           -0.092                11.830
# ...                               ...                   ...
# 4324                           -0.038                10.608
# 4325                           -0.080                12.888
# 4326                           -0.069                10.916
# 4488                           -0.149                12.395
# 4489                           -0.046                11.116
#
#       Ks_(2MASS)_Magnitude_Upper_Unc  Ks_(2MASS)_Magnitude_Lower_Unc  \
# 17                             0.029                          -0.029
# 1578                             NaN                             NaN
# 1579                             NaN                             NaN
# 1580                             NaN                             NaN
# 1581                           0.026                          -0.026
# ...                              ...                             ...
# 4324                           0.022                          -0.022
# 4325                           0.031                          -0.031
# 4326                           0.020                          -0.020
# 4488                           0.021                          -0.021
# 4489                           0.022                          -0.022
#
#       Gaia_Magnitude  Gaia_Magnitude_Upper_Unc  Gaia_Magnitude_Lower_Unc
# 17           12.1376                  0.003687                 -0.003687
# 1578         15.7109                  0.000974                 -0.000974
# 1579         15.7109                  0.000974                 -0.000974
# 1580         15.7109                  0.000974                 -0.000974
# 1581         13.1059                  0.000372                 -0.000372
# ...              ...                       ...                       ...
# 4324         11.8477                  0.000200                 -0.000200
# 4325         14.3408                  0.000233                 -0.000233
# 4326         12.2343                  0.000185                 -0.000185
# 4488         13.6988                  0.001604                 -0.001604
# 4489         12.5811                  0.000185                 -0.000185
#
# [2707 rows x 85 columns]

# %%
confirmed_planets_df = confirmed_planets_df.loc[confirmed_planets_df["Discovery_Method"] == "Transit" ]
confirmed_planets_df
# Out:
#       Unnamed: 0     Planet_Name     Host_Name  Number_of_Stars  \
# 1582        1582  KIC 10525077 b  KIC 10525077                1
# 1583        1583   KIC 3558849 b   KIC 3558849                1
# 1585        1585   KIC 5437945 b   KIC 5437945                1
# 1587        1587   KIC 5951458 b   KIC 5951458                2
# 1590        1590   KIC 8540376 b      KOI-7892                1
# ...          ...             ...           ...              ...
# 4324        4324    Kepler-997 b    Kepler-997                1
# 4325        4325    Kepler-998 b    Kepler-998                1
# 4326        4326    Kepler-999 b    Kepler-999                1
# 4488        4488           PH1 b           PH1                4
# 4489        4489           PH2 b           PH2                1
#
#       Number_of_Planets Discovery_Method  Discovery_Year Discovery_Facility  \
# 1582                  1          Transit            2015             Kepler
# 1583                  1          Transit            2015             Kepler
# 1585                  2          Transit            2015             Kepler
# 1587                  1          Transit            2015             Kepler
# 1590                  3          Transit            2015             Kepler
# ...                 ...              ...             ...                ...
# 4324                  1          Transit            2016             Kepler
# 4325                  1          Transit            2016             Kepler
# 4326                  1          Transit            2016             Kepler
# 4488                  1          Transit            2012             Kepler
# 4489                  1          Transit            2013             Kepler
#
#       Controversial_Flag  Orbital_Period_[days]  ...  Distance_[pc]_Lower_Unc  \
# 1582                   0             854.083000  ...                  -52.100
# 1583                   0            1322.300000  ...                  -32.410
# 1585                   0             440.781300  ...                  -27.920
# 1587                   1            1320.100000  ...                  -12.076
# 1590                   0              31.809900  ...                  -22.025
# ...                  ...                    ...  ...                      ...
# 4324                   0               2.707307  ...                   -5.574
# 4325                   0               5.653777  ...                  -15.197
# 4326                   0               5.991857  ...                   -7.962
# 4488                   0             138.317000  ...                      NaN
# 4489                   0             282.525500  ...                   -3.557
#
#       V_(Johnson)_Magnitude  V_(Johnson)_Magnitude_Upper_Unc  \
# 1582                 15.592                            0.115
# 1583                 14.320                            0.114
# 1585                 13.834                            0.114
# 1587                 12.836                            0.092
# 1590                 14.411                            0.114
# ...                     ...                              ...
# 4324                 11.521                            0.038
# 4325                 14.463                            0.080
# 4326                 12.364                            0.069
# 4488                 13.841                            0.149
# 4489                 12.645                            0.046
#
#       V_(Johnson)_Magnitude_Lower_Unc  Ks_(2MASS)_Magnitude  \
# 1582                           -0.115                13.754
# 1583                           -0.114                12.767
# 1585                           -0.114                12.367
# 1587                           -0.092                11.324
# 1590                           -0.114                12.966
# ...                               ...                   ...
# 4324                           -0.038                10.608
# 4325                           -0.080                12.888
# 4326                           -0.069                10.916
# 4488                           -0.149                12.395
# 4489                           -0.046                11.116
#
#       Ks_(2MASS)_Magnitude_Upper_Unc  Ks_(2MASS)_Magnitude_Lower_Unc  \
# 1582                           0.046                          -0.046
# 1583                           0.027                          -0.027
# 1585                           0.027                          -0.027
# 1587                           0.020                          -0.020
# 1590                           0.023                          -0.023
# ...                              ...                             ...
# 4324                           0.022                          -0.022
# 4325                           0.031                          -0.031
# 4326                           0.020                          -0.020
# 4488                           0.021                          -0.021
# 4489                           0.022                          -0.022
#
#       Gaia_Magnitude  Gaia_Magnitude_Upper_Unc  Gaia_Magnitude_Lower_Unc
# 1582         15.3043                  0.000404                 -0.000404
# 1583         14.1674                  0.000258                 -0.000258
# 1585         13.7506                  0.000290                 -0.000290
# 1587         12.6884                  0.000195                 -0.000195
# 1590         14.2165                  0.000257                 -0.000257
# ...              ...                       ...                       ...
# 4324         11.8477                  0.000200                 -0.000200
# 4325         14.3408                  0.000233                 -0.000233
# 4326         12.2343                  0.000185                 -0.000185
# 4488         13.6988                  0.001604                 -0.001604
# 4489         12.5811                  0.000185                 -0.000185
#
# [2677 rows x 85 columns]

# %%
confirmed_planets_df.nunique()
# Out:
# Unnamed: 0                        2677
# Planet_Name                       2677
# Host_Name                         1949
# Number_of_Stars                      4
# Number_of_Planets                    7
#                                   ...
# Ks_(2MASS)_Magnitude_Upper_Unc      75
# Ks_(2MASS)_Magnitude_Lower_Unc      75
# Gaia_Magnitude                    1864
# Gaia_Magnitude_Upper_Unc           632
# Gaia_Magnitude_Lower_Unc           632
# Length: 85, dtype: int64

# %%
for columns in confirmed_planets_df:
    
    confirmed = confirmed_planets_df[columns].value_counts()
    
    print(confirmed)
# Out:
# 1582    1
# 3403    1
# 3405    1
# 3406    1
# 3407    1
#        ..
# 2512    1
# 2513    1
# 2514    1
# 2515    1
# 4489    1
# Name: Unnamed: 0, Length: 2677, dtype: int64
# KIC 10525077 b    1
# Kepler-358 b      1
# Kepler-359 b      1
# Kepler-359 c      1
# Kepler-359 d      1
#                  ..
# Kepler-164 b      1
# Kepler-164 c      1
# Kepler-164 d      1
# Kepler-1640 b     1
# PH2 b             1
# Name: Planet_Name, Length: 2677, dtype: int64
# KOI-351        8
# Kepler-11      6
# Kepler-80      6
# Kepler-32      5
# Kepler-186     5
#               ..
# Kepler-1620    1
# Kepler-1619    1
# Kepler-1618    1
# Kepler-1617    1
# PH2            1
# Name: Host_Name, Length: 1949, dtype: int64
# 1    2565
# 2     104
# 3       7
# 4       1
# Name: Number_of_Stars, dtype: int64
# 1    1466
# 2     588
# 3     357
# 4     163
# 5      78
# 6      17
# 8       8
# Name: Number_of_Planets, dtype: int64
# Transit    2677
# Name: Discovery_Method, dtype: int64
# 2016    1285
# 2014     768
# 2021     307
# 2013      72
# 2012      58
# 2020      56
# 2011      51
# 2015      46
# 2010      12
# 2017       8
# 2018       6
# 2019       4
# 2009       4
# Name: Discovery_Year, dtype: int64
# Kepler    2677
# Name: Discovery_Facility, dtype: int64
# 0    2674
# 1       3
# Name: Controversial_Flag, dtype: int64
# 854.083000    1
# 34.060467     1
# 25.563222     1
# 57.688020     1
# 77.095691     1
#              ..
# 5.035030      1
# 10.945723     1
# 28.986769     1
# 7.584413      1
# 282.525500    1
# Name: Orbital_Period_[days], Length: 2677, dtype: int64
# 0.000008    17
# 0.000020    15
# 0.000006    14
# 0.000019    13
# 0.000010    13
#             ..
# 0.000094     1
# 0.000026     1
# 0.000044     1
# 0.000512     1
# 0.040000     1
# Name: Orbital_Period_Upper_Unc._[days], Length: 1576, dtype: int64
# -0.000008    17
# -0.000006    15
# -0.000020    15
# -0.000009    13
# -0.000010    13
#              ..
# -0.000081     1
# -0.001150     1
# -0.000322     1
# -0.000084     1
# -0.000011     1
# Name: Orbital_Period_Lower_Unc._[days], Length: 1569, dtype: int64
# 0.0    2677
# Name: Orbital_Period_Limit_Flag, dtype: int64
# 0.08700    11
# 0.07500    11
# 0.06500    11
# 0.06400    11
# 0.05400    10
#            ..
# 0.03360     1
# 0.97120     1
# 0.05511     1
# 0.70480     1
# 0.82800     1
# Name: Orbit_Semi-Major_Axis_[au]), Length: 1578, dtype: int64
# 0.0010    9
# 0.0020    9
# 0.0040    8
# 0.0009    6
# 0.0011    6
#          ..
# 0.0580    1
# 0.0098    1
# 0.0042    1
# 0.0108    1
# 0.0090    1
# Name: Orbit_Semi-Major_Axis_Upper_Unc._[au], Length: 132, dtype: int64
# -0.00200    8
# -0.00100    8
# -0.00300    7
# -0.00110    7
# -0.00400    6
#            ..
# -0.02100    1
# -0.03500    1
# -0.00410    1
# -0.00750    1
# -0.00129    1
# Name: Orbit_Semi-Major_Axis_Lower_Unc._[au], Length: 125, dtype: int64
# 0.0    2668
# Name: Orbit_Semi-Major_Axis_Limit_Flag, dtype: int64
# 1.640     18
# 1.320     17
# 1.330     16
# 1.990     16
# 1.460     16
#           ..
# 2.799      1
# 3.163      1
# 2.319      1
# 2.379      1
# 10.120     1
# Name: Planet_Radius_[Earth_Radius], Length: 896, dtype: int64
# 0.090    69
# 0.100    61
# 0.080    57
# 0.120    55
# 0.060    50
#          ..
# 2.720     1
# 0.038     1
# 1.140     1
# 2.370     1
# 1.650     1
# Name: Planet_Radius_Upper_Unc._[Earth_Radius], Length: 284, dtype: int64
# -0.080    76
# -0.100    74
# -0.110    70
# -0.090    68
# -0.140    67
#           ..
# -1.140     1
# -1.660     1
# -1.860     1
# -1.470     1
# -0.673     1
# Name: Planet_Radius_Lower_Unc._[Earth_Radius], Length: 246, dtype: int64
# 0.0    2677
# Name: Planet_Radius_Limit_Flag, dtype: int64
# 0.178    31
# 0.136    28
# 0.211    25
# 0.128    22
# 0.112    21
#          ..
# 0.059     1
# 0.320     1
# 0.474     1
# 0.530     1
# 0.903     1
# Name: Planet_Radius_[Jupiter_Radius], Length: 536, dtype: int64
# 0.012    86
# 0.008    70
# 0.004    65
# 0.009    64
# 0.007    61
#          ..
# 2.378     1
# 0.210     1
# 0.260     1
# 0.180     1
# 0.147     1
# Name: Planet_Radius_Upper_Unc._[Jupiter_Radius], Length: 203, dtype: int64
# -0.012    133
# -0.007     79
# -0.021     78
# -0.004     77
# -0.009     76
#          ...
# -0.133      1
# -0.118      1
# -0.166      1
# -0.141      1
# -0.204      1
# Name: Planet_Radius_Lower_Unc._[Jupiter_Radius], Length: 168, dtype: int64
# 0.0    2677
# Name: Planet_Radius_Limit_Flag.1, dtype: int64
# 3.33        18
# 2.73        17
# 4.50        17
# 2.33        16
# 2.30        16
#             ..
# 7.99         1
# 2.58         1
# 6.01         1
# 14.60        1
# 25426.40     1
# Name: Planet_Mass_or_Mass*sin(i)_[Earth_Mass], Length: 839, dtype: int64
# 1.40000     6
# 1.50000     5
# 1.70000     5
# 1.10000     4
# 25.43000    4
#            ..
# 22.50000    1
# 71.70000    1
# 43.30000    1
# 20.00000    1
# 0.84796     1
# Name: Planet_Mass_or_Mass*sin(i)_[Earth_Mass]_Upper_Unc., Length: 207, dtype: int64
# -1.10000     6
# -1.60000     6
# -1.80000     6
# -3.60000     5
# -1.30000     5
#             ..
# -33.20000    1
# -1.72000     1
# -10.10000    1
# -19.10000    1
# -0.84796     1
# Name: Planet_Mass_or_Mass*sin(i)_[Earth_Mass]_Lower_Unc., Length: 201, dtype: int64
# 0.0    2597
# 1.0      64
# Name: Planet_Mass_or_Mass*sin(i)_[Earth_Mass]_Limit_Flag, dtype: int64
# 0.01050     18
# 0.00733     16
# 0.01420     16
# 0.00859     16
# 0.01450     15
#             ..
# 0.03850      1
# 0.00858      1
# 0.01290      1
# 0.00874      1
# 80.00000     1
# Name: Planet_Mass_or_Mass*sin(i)_[Jupiter_Mass], Length: 832, dtype: int64
# 0.00600    8
# 0.00400    7
# 0.02000    5
# 0.01000    5
# 0.00300    5
#           ..
# 0.07000    1
# 0.57700    1
# 1.31900    1
# 0.01249    1
# 0.00267    1
# Name: Planet_Mass_or_Mass*sin(i)_[Jupiter_Mass]_Upper_Unc., Length: 177, dtype: int64
# -0.00600    8
# -0.00300    6
# -0.00500    6
# -0.01100    6
# -0.00400    6
#            ..
# -0.00541    1
# -0.10400    1
# -1.08500    1
# -0.01164    1
# -0.04400    1
# Name: Planet_Mass_or_Mass*sin(i)_[Jupiter_Mass]_Lower_Unc., Length: 172, dtype: int64
# 0.0    2597
# 1.0      64
# Name: Planet_Mass_or_Mass*sin(i)_[Jupiter_Mass]_Limit_Flag, dtype: int64
# M-R relationship    2312
# Mass                 348
# Msini                 17
# Name: Planet_Mass_or_Mass*sin(i)_Provenance, dtype: int64
# 0.000    2482
# 0.030      12
# 0.020      11
# 0.040       9
# 0.330       7
#          ...
# 0.078       1
# 0.400       1
# 0.033       1
# 0.921       1
# 0.410       1
# Name: Eccentricity, Length: 111, dtype: int64
# 0.0100    7
# 0.1000    7
# 0.0800    6
# 0.2400    5
# 0.0700    5
#          ..
# 0.2600    1
# 0.3900    1
# 0.0023    1
# 0.0049    1
# 0.0029    1
# Name: Eccentricity_Upper_Unc., Length: 87, dtype: int64
# -0.020    14
# -0.030    12
# -0.040     9
# -0.010     9
# -0.100     5
#           ..
# -0.059     1
# -0.160     1
# -0.051     1
# -0.130     1
# -0.290     1
# Name: Eccentricity_Lower_Unc., Length: 80, dtype: int64
#  0.0    2641
#  1.0      18
# -1.0       9
# Name: Eccentricity_Limit_Flag, dtype: int64
# 5.99      4
# 6.22      3
# 7.29      3
# 1.99      3
# 1.85      3
#          ..
# 131.49    1
# 35.89     1
# 537.40    1
# 82.83     1
# 1.21      1
# Name: Insolation_Flux_[Earth_Flux], Length: 2520, dtype: int64
# 0.20      12
# 0.14      11
# 0.06      11
# 0.12      11
# 0.46      10
#           ..
# 30.36      1
# 114.62     1
# 38.77      1
# 111.26     1
# 27.87      1
# Name: Insolation_Flux_Upper_Unc._[Earth_Flux], Length: 1678, dtype: int64
# -0.07      12
# -0.06      12
# -0.23      11
# -0.14      11
# -0.44      10
#            ..
# -31.09      1
# -38.24      1
# -176.30     1
# -4.68       1
# -26.67      1
# Name: Insolation_Flux_Lower_Unc._[Earth_Flux], Length: 1596, dtype: int64
# 0.0    2654
# Name: Insolation_Flux_Limit_Flag, dtype: int64
# 678.0    8
# 806.0    8
# 401.0    8
# 554.0    8
# 786.0    7
#         ..
# 304.0    1
# 200.0    1
# 282.0    1
# 182.0    1
# 281.0    1
# Name: Equilibrium_Temperature_[K], Length: 1164, dtype: int64
# 20.0     6
# 27.0     5
# 10.0     5
# 15.0     5
# 50.0     4
# 19.0     4
# 16.0     4
# 4.0      4
# 21.0     4
# 26.0     4
# 18.0     3
# 11.0     3
# 30.0     3
# 13.0     3
# 12.0     3
# 28.0     3
# 14.0     3
# 9.0      3
# 25.0     3
# 22.0     3
# 40.0     2
# 70.0     2
# 24.0     2
# 200.0    2
# 45.0     2
# 6.0      2
# 17.0     2
# 39.0     2
# 120.0    2
# 73.0     2
# 29.0     2
# 31.0     2
# 8.0      1
# 41.0     1
# 90.0     1
# 47.0     1
# 87.0     1
# 750.0    1
# 36.0     1
# 60.0     1
# 52.0     1
# 75.0     1
# 100.0    1
# 51.0     1
# 55.0     1
# 32.0     1
# 38.0     1
# 43.0     1
# 67.0     1
# 37.0     1
# 2.0      1
# 80.0     1
# 46.0     1
# 228.0    1
# 238.0    1
# 103.0    1
# 23.0     1
# 7.0      1
# Name: Equilibrium_Temperature_Upper_Unc._[K], dtype: int64
# -20.0     9
# -10.0     6
# -13.0     5
# -4.0      4
# -11.0     4
# -16.0     4
# -17.0     4
# -15.0     4
# -32.0     3
# -18.0     3
# -40.0     3
# -27.0     3
# -29.0     3
# -30.0     3
# -14.0     3
# -31.0     3
# -19.0     3
# -22.0     3
# -26.0     3
# -52.0     2
# -200.0    2
# -25.0     2
# -36.0     2
# -45.0     2
# -120.0    2
# -47.0     2
# -70.0     2
# -21.0     2
# -50.0     2
# -60.0     2
# -12.0     2
# -5.0      2
# -28.0     2
# -9.0      2
# -41.0     2
# -75.0     1
# -750.0    1
# -51.0     1
# -90.0     1
# -6.0      1
# -8.0      1
# -87.0     1
# -23.0     1
# -80.0     1
# -73.0     1
# -145.0    1
# -46.0     1
# -210.0    1
# -228.0    1
# -37.0     1
# -39.0     1
# -3.0      1
# -24.0     1
# -107.0    1
# -7.0      1
# Name: Equilibrium_Temperature_Lower_Unc._[K], dtype: int64
# 0.0    2658
# Name: Equilibrium_Temperature_Limit_Flag, dtype: int64
# 0    2396
# 1     281
# Name: Data_show_Transit_Timing_Variations, dtype: int64
# M0 V     37
# M1 V     29
# K2 V      8
# M2 V      8
# M4        6
# G4 V      6
# K5        6
# K         6
# M1        5
# M         4
# G5 V      4
# G2 V      4
# K4        4
# F8 V      4
# K7 V      3
# G0 V      2
# G6 V      2
# G3 IV     2
# K1 V      2
# G8 V      1
# G         1
# K0 V      1
# G9 V      1
# G2        1
# K3        1
# F5 IV     1
# G2 IV     1
# G1 V      1
# G9/K0     1
# G3 V      1
# F7 V      1
# F6 IV     1
# F         1
# Name: Spectral_Type, dtype: int64
# 5526.0    12
# 5774.0    10
# 5904.0     9
# 6090.0     9
# 6012.0     9
#           ..
# 3713.0     1
# 3638.0     1
# 4807.0     1
# 6148.0     1
# 6407.0     1
# Name: Stellar_Effective_Temperature_[K], Length: 1321, dtype: int64
# 100.00    283
# 200.00    257
# 74.00      29
# 75.00      29
# 60.00      28
#          ...
# 119.66      1
# 42.43       1
# 43.62       1
# 49.81       1
# 42.00       1
# Name: Stellar_Effective_Temperature_Upper_Unc._[K], Length: 1312, dtype: int64
# -100.00    281
# -200.00    260
# -74.00      31
# -60.00      28
# -150.00     27
#           ...
# -70.11       1
# -112.92      1
# -186.17      1
# -94.04       1
# -45.00       1
# Name: Stellar_Effective_Temperature_Lower_Unc._[K], Length: 1348, dtype: int64
# 0.0    2677
# Name: Stellar_Effective_Temperature_Limit_Flag, dtype: int64
# 0.80    59
# 0.94    56
# 0.90    56
# 0.89    55
# 0.84    53
#         ..
# 1.62     1
# 2.51     1
# 1.96     1
# 0.36     1
# 2.01     1
# Name: Stellar_Radius_[Solar_Radius], Length: 189, dtype: int64
# 0.03    230
# 0.02    220
# 0.05    147
# 0.04    145
# 0.06     87
#        ...
# 0.91      1
# 0.78      1
# 1.02      1
# 0.82      1
# 0.83      1
# Name: Stellar_Radius_Upper_Unc._[Solar_Radius], Length: 78, dtype: int64
# -0.04    229
# -0.05    211
# -0.03    205
# -0.02    194
# -0.06    168
#         ...
# -0.71      1
# -1.02      1
# -0.87      1
# -1.11      1
# -0.82      1
# Name: Stellar_Radius_Lower_Unc._[Solar_Radius], Length: 68, dtype: int64
# 0.0    2677
# Name: Stellar_Radius_Limit_Flag, dtype: int64
# 0.94    89
# 0.95    81
# 0.98    80
# 0.96    75
# 1.02    72
#         ..
# 1.38     1
# 0.28     1
# 0.45     1
# 0.24     1
# 1.53     1
# Name: Stellar_Mass_[Solar_mass], Length: 127, dtype: int64
# 0.04    581
# 0.03    333
# 0.05    331
# 0.06    314
# 0.07    183
# 0.02    161
# 0.08    101
# 0.09     96
# 0.10     81
# 0.11     55
# 0.01     54
# 0.12     52
# 0.13     49
# 0.14     40
# 0.17     30
# 0.16     25
# 0.15     24
# 0.20     21
# 0.22     18
# 0.21     17
# 0.18     12
# 0.19     11
# 0.23      8
# 0.41      3
# 0.25      3
# 0.24      2
# 0.00      2
# 0.38      2
# 0.42      2
# 0.40      2
# 0.26      1
# 1.00      1
# 0.32      1
# Name: Stellar_Mass_Upper_Unc._[Solar_mass], dtype: int64
# -0.04    557
# -0.05    461
# -0.06    403
# -0.03    297
# -0.07    202
# -0.02    129
# -0.08    109
# -0.09     88
# -0.10     64
# -0.12     58
# -0.01     50
# -0.14     41
# -0.11     40
# -0.16     29
# -0.13     25
# -0.15     15
# -0.17     15
# -0.23      5
# -0.18      4
# -0.19      4
# -0.20      4
# -0.21      3
#  0.00      2
# -0.25      2
# -0.29      2
# -0.27      2
# -0.34      1
# -0.26      1
# -0.22      1
# -0.32      1
# Name: Stellar_Mass_Lower_Unc._[Solar_mass], dtype: int64
# 0.0    2677
# Name: Stellar_Mass_Limit_Flag, dtype: int64
#  0.040    128
#  0.030    122
#  0.000    122
#  0.020    109
#  0.010    102
#          ...
#  0.106      1
#  0.108      1
#  0.056      1
#  0.228      1
# -0.078      1
# Name: Stellar_Metallicity_[dex], Length: 237, dtype: int64
# 0.150    280
# 0.100     89
# 0.300     74
# 0.013     61
# 0.250     55
#         ...
# 0.029      1
# 0.178      1
# 0.470      1
# 0.175      1
# 0.184      1
# Name: Stellar_Metallicity_Upper_Unc._[dex], Length: 191, dtype: int64
# -0.150    243
# -0.300    152
# -0.100    117
# -0.013     63
# -0.014     50
#          ...
# -0.219      1
# -0.220      1
# -0.226      1
# -0.290      1
# -0.214      1
# Name: Stellar_Metallicity_Lower_Unc._[dex], Length: 226, dtype: int64
# 0.0    2677
# Name: Stellar_Metallicity_Limit_Flag, dtype: int64
# [Fe/H]    2274
# [M/H]      384
# [m/H]       15
# [Me/H]       4
# Name: Stellar_Metallicity_Ratio, dtype: int64
# 4.49    90
# 4.47    85
# 4.50    83
# 4.56    81
# 4.58    80
#         ..
# 5.01     1
# 3.49     1
# 4.83     1
# 3.99     1
# 2.95     1
# Name: Stellar_Surface_Gravity_[log10(cm/s**2)], Length: 120, dtype: int64
# 0.15    362
# 0.30    278
# 0.04    225
# 0.03    212
# 0.05    201
# 0.02    186
# 0.07    170
# 0.01    168
# 0.06    160
# 0.10    123
# 0.08    109
# 0.09     93
# 0.11     60
# 0.12     49
# 0.14     43
# 0.20     40
# 0.13     33
# 0.16     17
# 0.17     16
# 0.18     16
# 0.00     10
# 0.23      7
# 0.19      7
# 0.25      6
# 0.21      3
# 0.24      3
# 0.35      2
# 0.28      2
# 0.62      2
# 0.46      1
# 0.40      1
# 0.50      1
# 0.36      1
# 0.71      1
# 0.22      1
# 0.32      1
# Name: Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)], dtype: int64
# -0.15    394
# -0.30    286
# -0.10    148
# -0.01    134
# -0.02    130
# -0.11    122
# -0.03    119
# -0.04    106
# -0.12    101
# -0.07    101
# -0.06    101
# -0.05     92
# -0.13     82
# -0.20     80
# -0.09     72
# -0.14     70
# -0.08     62
# -0.16     58
# -0.18     57
# -0.19     55
# -0.17     54
# -0.21     38
# -0.22     31
# -0.25     27
# -0.23     25
# -0.24     22
# -0.26     15
#  0.00     10
# -0.27      4
# -0.28      3
# -0.33      2
# -0.32      2
# -0.35      2
# -0.50      1
# -0.58      1
# -0.43      1
# -3.51      1
# -0.34      1
# Name: Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)], dtype: int64
# 0.0    2677
# Name: Stellar_Surface_Gravity_Limit_Flag, dtype: int64
# 18h57m44.03s    8
# 19h44m27.02s    6
# 19h48m27.62s    6
# 19h10m47.52s    5
# 19h51m22.15s    5
#                ..
# 19h50m21.25s    1
# 19h49m05.02s    1
# 19h02m48.86s    1
# 19h40m42.09s    1
# 19h19m03.27s    1
# Name: RA_[sexagesimal], Length: 1946, dtype: int64
# 284.433464    8
# 297.115095    6
# 296.112576    6
# 297.842307    5
# 298.652736    5
#              ..
# 297.270903    1
# 285.703595    1
# 295.175362    1
# 287.937175    1
# 289.763621    1
# Name: RA_[deg], Length: 1949, dtype: int64
# +49d18m18.45s    8
# +41d54m32.79s    6
# +39d58m43.48s    6
# +46d34m27.69s    5
# +43d57m17.96s    5
#                 ..
# +46d55m42.51s    1
# +44d25m19.75s    1
# +45d55m51.09s    1
# +46d25m06.52s    1
# +51d57m45.66s    1
# Name: Dec_[sexagesimal], Length: 1949, dtype: int64
# 49.305124    8
# 41.909109    6
# 39.978745    6
# 46.574359    5
# 43.954988    5
#             ..
# 46.928474    1
# 44.422153    1
# 45.930859    1
# 46.418478    1
# 51.962683    1
# Name: Dec_[deg], Length: 1949, dtype: int64
# 848.254     8
# 646.346     6
# 369.451     6
# 578.796     5
# 891.092     5
#            ..
# 734.850     1
# 1229.250    1
# 898.310     1
# 1137.810    1
# 343.863     1
# Name: Distance_[pc], Length: 1932, dtype: int64
# 10.8185    8
# 16.9200    8
# 6.3750     6
# 6.7435     6
# 2.8945     6
#           ..
# 12.7090    1
# 17.5300    1
# 39.1500    1
# 46.1800    1
# 3.6310     1
# Name: Distance_[pc]_Upper_Unc, Length: 1828, dtype: int64
# -10.8185    8
# -42.1900    7
# -18.6400    6
# -6.7435     6
# -2.8945     6
#            ..
# -17.5300    1
# -37.1100    1
# -42.9100    1
# -60.0000    1
# -3.5570     1
# Name: Distance_[pc]_Lower_Unc, Length: 1835, dtype: int64
# 14.379    9
# 13.965    8
# 15.161    8
# 13.883    8
# 16.303    7
#          ..
# 16.069    1
# 11.620    1
# 11.640    1
# 11.045    1
# 13.841    1
# Name: V_(Johnson)_Magnitude, Length: 1561, dtype: int64
# 0.0800    259
# 0.0920    253
# 0.1030    207
# 0.0690    204
# 0.1260    198
#          ...
# 0.0090      1
# 0.0491      1
# 0.0310      1
# 0.0464      1
# 0.0380      1
# Name: V_(Johnson)_Magnitude_Upper_Unc, Length: 113, dtype: int64
# -0.0800    259
# -0.0920    253
# -0.1030    207
# -0.0690    204
# -0.1260    198
#           ...
# -0.0090      1
# -0.0491      1
# -0.0310      1
# -0.0464      1
# -0.0380      1
# Name: V_(Johnson)_Magnitude_Lower_Unc, Length: 113, dtype: int64
# 12.482    9
# 13.512    8
# 12.383    8
# 12.826    8
# 13.343    8
#          ..
# 12.661    1
# 14.087    1
# 13.434    1
# 14.059    1
# 11.116    1
# Name: Ks_(2MASS)_Magnitude, Length: 1492, dtype: int64
# 0.021    152
# 0.020    136
# 0.023    136
# 0.018    136
# 0.019    111
#         ...
# 0.089      1
# 0.075      1
# 0.077      1
# 0.094      1
# 0.084      1
# Name: Ks_(2MASS)_Magnitude_Upper_Unc, Length: 75, dtype: int64
# -0.021    152
# -0.020    136
# -0.023    136
# -0.018    136
# -0.019    111
#          ...
# -0.089      1
# -0.075      1
# -0.077      1
# -0.094      1
# -0.084      1
# Name: Ks_(2MASS)_Magnitude_Lower_Unc, Length: 75, dtype: int64
# 13.7397    8
# 14.7555    6
# 15.0151    6
# 13.7062    6
# 14.5994    5
#           ..
# 14.2242    1
# 15.7627    1
# 15.6681    1
# 14.9243    1
# 12.5811    1
# Name: Gaia_Magnitude, Length: 1864, dtype: int64
# 0.000273    25
# 0.000236    21
# 0.000254    17
# 0.000217    17
# 0.000268    16
#             ..
# 0.000489     1
# 0.000785     1
# 0.000773     1
# 0.000589     1
# 0.001604     1
# Name: Gaia_Magnitude_Upper_Unc, Length: 632, dtype: int64
# -0.000273    25
# -0.000236    21
# -0.000254    17
# -0.000217    17
# -0.000268    16
#              ..
# -0.000489     1
# -0.000785     1
# -0.000773     1
# -0.000589     1
# -0.001604     1
# Name: Gaia_Magnitude_Lower_Unc, Length: 632, dtype: int64

# %%
confirmed_planets_df = confirmed_planets_df.loc[confirmed_planets_df["Controversial_Flag" ] == 0]
confirmed_planets_df
# Out:
#       Unnamed: 0     Planet_Name     Host_Name  Number_of_Stars  \
# 1582        1582  KIC 10525077 b  KIC 10525077                1
# 1583        1583   KIC 3558849 b   KIC 3558849                1
# 1585        1585   KIC 5437945 b   KIC 5437945                1
# 1590        1590   KIC 8540376 b      KOI-7892                1
# 1591        1591   KIC 8540376 c      KOI-7892                1
# ...          ...             ...           ...              ...
# 4324        4324    Kepler-997 b    Kepler-997                1
# 4325        4325    Kepler-998 b    Kepler-998                1
# 4326        4326    Kepler-999 b    Kepler-999                1
# 4488        4488           PH1 b           PH1                4
# 4489        4489           PH2 b           PH2                1
#
#       Number_of_Planets Discovery_Method  Discovery_Year Discovery_Facility  \
# 1582                  1          Transit            2015             Kepler
# 1583                  1          Transit            2015             Kepler
# 1585                  2          Transit            2015             Kepler
# 1590                  3          Transit            2015             Kepler
# 1591                  3          Transit            2015             Kepler
# ...                 ...              ...             ...                ...
# 4324                  1          Transit            2016             Kepler
# 4325                  1          Transit            2016             Kepler
# 4326                  1          Transit            2016             Kepler
# 4488                  1          Transit            2012             Kepler
# 4489                  1          Transit            2013             Kepler
#
#       Controversial_Flag  Orbital_Period_[days]  ...  Distance_[pc]_Lower_Unc  \
# 1582                   0             854.083000  ...                  -52.100
# 1583                   0            1322.300000  ...                  -32.410
# 1585                   0             440.781300  ...                  -27.920
# 1590                   0              31.809900  ...                  -22.025
# 1591                   0              75.200000  ...                  -22.025
# ...                  ...                    ...  ...                      ...
# 4324                   0               2.707307  ...                   -5.574
# 4325                   0               5.653777  ...                  -15.197
# 4326                   0               5.991857  ...                   -7.962
# 4488                   0             138.317000  ...                      NaN
# 4489                   0             282.525500  ...                   -3.557
#
#       V_(Johnson)_Magnitude  V_(Johnson)_Magnitude_Upper_Unc  \
# 1582                 15.592                            0.115
# 1583                 14.320                            0.114
# 1585                 13.834                            0.114
# 1590                 14.411                            0.114
# 1591                 14.411                            0.114
# ...                     ...                              ...
# 4324                 11.521                            0.038
# 4325                 14.463                            0.080
# 4326                 12.364                            0.069
# 4488                 13.841                            0.149
# 4489                 12.645                            0.046
#
#       V_(Johnson)_Magnitude_Lower_Unc  Ks_(2MASS)_Magnitude  \
# 1582                           -0.115                13.754
# 1583                           -0.114                12.767
# 1585                           -0.114                12.367
# 1590                           -0.114                12.966
# 1591                           -0.114                12.966
# ...                               ...                   ...
# 4324                           -0.038                10.608
# 4325                           -0.080                12.888
# 4326                           -0.069                10.916
# 4488                           -0.149                12.395
# 4489                           -0.046                11.116
#
#       Ks_(2MASS)_Magnitude_Upper_Unc  Ks_(2MASS)_Magnitude_Lower_Unc  \
# 1582                           0.046                          -0.046
# 1583                           0.027                          -0.027
# 1585                           0.027                          -0.027
# 1590                           0.023                          -0.023
# 1591                           0.023                          -0.023
# ...                              ...                             ...
# 4324                           0.022                          -0.022
# 4325                           0.031                          -0.031
# 4326                           0.020                          -0.020
# 4488                           0.021                          -0.021
# 4489                           0.022                          -0.022
#
#       Gaia_Magnitude  Gaia_Magnitude_Upper_Unc  Gaia_Magnitude_Lower_Unc
# 1582         15.3043                  0.000404                 -0.000404
# 1583         14.1674                  0.000258                 -0.000258
# 1585         13.7506                  0.000290                 -0.000290
# 1590         14.2165                  0.000257                 -0.000257
# 1591         14.2165                  0.000257                 -0.000257
# ...              ...                       ...                       ...
# 4324         11.8477                  0.000200                 -0.000200
# 4325         14.3408                  0.000233                 -0.000233
# 4326         12.2343                  0.000185                 -0.000185
# 4488         13.6988                  0.001604                 -0.001604
# 4489         12.5811                  0.000185                 -0.000185
#
# [2674 rows x 85 columns]

# %%
mergable_confirmed_planets_df = confirmed_planets_df.loc[confirmed_planets_df["Orbit_Semi-Major_Axis_Limit_Flag" ] == 0.0]
mergable_confirmed_planets_df
# Out:
#       Unnamed: 0    Planet_Name    Host_Name  Number_of_Stars  \
# 1585        1585  KIC 5437945 b  KIC 5437945                1
# 1592        1592  KIC 9663113 b  KIC 9663113                1
# 1619        1619       KOI-12 b       KOI-12                1
# 1620        1620     KOI-1257 b     KOI-1257                2
# 1621        1621       KOI-13 b       KOI-13                3
# ...          ...            ...          ...              ...
# 4324        4324   Kepler-997 b   Kepler-997                1
# 4325        4325   Kepler-998 b   Kepler-998                1
# 4326        4326   Kepler-999 b   Kepler-999                1
# 4488        4488          PH1 b          PH1                4
# 4489        4489          PH2 b          PH2                1
#
#       Number_of_Planets Discovery_Method  Discovery_Year Discovery_Facility  \
# 1585                  2          Transit            2015             Kepler
# 1592                  2          Transit            2015             Kepler
# 1619                  2          Transit            2015             Kepler
# 1620                  1          Transit            2014             Kepler
# 1621                  1          Transit            2011             Kepler
# ...                 ...              ...             ...                ...
# 4324                  1          Transit            2016             Kepler
# 4325                  1          Transit            2016             Kepler
# 4326                  1          Transit            2016             Kepler
# 4488                  1          Transit            2012             Kepler
# 4489                  1          Transit            2013             Kepler
#
#       Controversial_Flag  Orbital_Period_[days]  ...  Distance_[pc]_Lower_Unc  \
# 1585                   0             440.781300  ...                  -27.920
# 1592                   0             572.384700  ...                  -44.335
# 1619                   0              17.855182  ...                   -4.303
# 1620                   0              86.647661  ...                  -39.926
# 1621                   0               1.763588  ...                  -27.506
# ...                  ...                    ...  ...                      ...
# 4324                   0               2.707307  ...                   -5.574
# 4325                   0               5.653777  ...                  -15.197
# 4326                   0               5.991857  ...                   -7.962
# 4488                   0             138.317000  ...                      NaN
# 4489                   0             282.525500  ...                   -3.557
#
#       V_(Johnson)_Magnitude  V_(Johnson)_Magnitude_Upper_Unc  \
# 1585                 13.834                            0.114
# 1592                 14.027                            0.137
# 1619                 11.510                            0.014
# 1620                 14.818                            0.069
# 1621                  9.791                            0.023
# ...                     ...                              ...
# 4324                 11.521                            0.038
# 4325                 14.463                            0.080
# 4326                 12.364                            0.069
# 4488                 13.841                            0.149
# 4489                 12.645                            0.046
#
#       V_(Johnson)_Magnitude_Lower_Unc  Ks_(2MASS)_Magnitude  \
# 1585                           -0.114                12.367
# 1592                           -0.137                12.502
# 1619                           -0.014                10.234
# 1620                           -0.069                12.726
# 1621                           -0.023                 9.425
# ...                               ...                   ...
# 4324                           -0.038                10.608
# 4325                           -0.080                12.888
# 4326                           -0.069                10.916
# 4488                           -0.149                12.395
# 4489                           -0.046                11.116
#
#       Ks_(2MASS)_Magnitude_Upper_Unc  Ks_(2MASS)_Magnitude_Lower_Unc  \
# 1585                           0.027                          -0.027
# 1592                           0.023                          -0.023
# 1619                           0.018                          -0.018
# 1620                           0.023                          -0.023
# 1621                           0.014                          -0.014
# ...                              ...                             ...
# 4324                           0.022                          -0.022
# 4325                           0.031                          -0.031
# 4326                           0.020                          -0.020
# 4488                           0.021                          -0.021
# 4489                           0.022                          -0.022
#
#       Gaia_Magnitude  Gaia_Magnitude_Upper_Unc  Gaia_Magnitude_Lower_Unc
# 1585         13.7506                  0.000290                 -0.000290
# 1592         13.9075                  0.000225                 -0.000225
# 1619         11.2535                  0.000523                 -0.000523
# 1620         14.6419                  0.000490                 -0.000490
# 1621         10.3678                  0.001225                 -0.001225
# ...              ...                       ...                       ...
# 4324         11.8477                  0.000200                 -0.000200
# 4325         14.3408                  0.000233                 -0.000233
# 4326         12.2343                  0.000185                 -0.000185
# 4488         13.6988                  0.001604                 -0.001604
# 4489         12.5811                  0.000185                 -0.000185
#
# [2666 rows x 85 columns]

# %%
mergable_confirmed_planets_df = mergable_confirmed_planets_df.set_index("Planet_Name")
mergable_confirmed_planets_df
# Out:
#                Unnamed: 0    Host_Name  Number_of_Stars  Number_of_Planets  \
# Planet_Name
# KIC 5437945 b        1585  KIC 5437945                1                  2
# KIC 9663113 b        1592  KIC 9663113                1                  2
# KOI-12 b             1619       KOI-12                1                  2
# KOI-1257 b           1620     KOI-1257                2                  1
# KOI-13 b             1621       KOI-13                3                  1
# ...                   ...          ...              ...                ...
# Kepler-997 b         4324   Kepler-997                1                  1
# Kepler-998 b         4325   Kepler-998                1                  1
# Kepler-999 b         4326   Kepler-999                1                  1
# PH1 b                4488          PH1                4                  1
# PH2 b                4489          PH2                1                  1
#
#               Discovery_Method  Discovery_Year Discovery_Facility  \
# Planet_Name
# KIC 5437945 b          Transit            2015             Kepler
# KIC 9663113 b          Transit            2015             Kepler
# KOI-12 b               Transit            2015             Kepler
# KOI-1257 b             Transit            2014             Kepler
# KOI-13 b               Transit            2011             Kepler
# ...                        ...             ...                ...
# Kepler-997 b           Transit            2016             Kepler
# Kepler-998 b           Transit            2016             Kepler
# Kepler-999 b           Transit            2016             Kepler
# PH1 b                  Transit            2012             Kepler
# PH2 b                  Transit            2013             Kepler
#
#                Controversial_Flag  Orbital_Period_Upper_Unc._[days]  \
# Planet_Name
# KIC 5437945 b                   0                          0.005630
# KIC 9663113 b                   0                          0.005830
# KOI-12 b                        0                          0.000008
# KOI-1257 b                      0                          0.000034
# KOI-13 b                        0                          0.000001
# ...                           ...                               ...
# Kepler-997 b                    0                          0.000006
# Kepler-998 b                    0                          0.000011
# Kepler-999 b                    0                          0.000008
# PH1 b                           0                          0.040000
# PH2 b                           0                          0.001000
#
#                Orbital_Period_Lower_Unc._[days]  ...  Distance_[pc]_Lower_Unc  \
# Planet_Name                                      ...
# KIC 5437945 b                         -0.005770  ...                  -27.920
# KIC 9663113 b                         -0.005670  ...                  -44.335
# KOI-12 b                              -0.000006  ...                   -4.303
# KOI-1257 b                            -0.000034  ...                  -39.926
# KOI-13 b                              -0.000001  ...                  -27.506
# ...                                         ...  ...                      ...
# Kepler-997 b                          -0.000006  ...                   -5.574
# Kepler-998 b                          -0.000011  ...                  -15.197
# Kepler-999 b                          -0.000008  ...                   -7.962
# PH1 b                                 -0.027000  ...                      NaN
# PH2 b                                 -0.001000  ...                   -3.557
#
#                V_(Johnson)_Magnitude  V_(Johnson)_Magnitude_Upper_Unc  \
# Planet_Name
# KIC 5437945 b                 13.834                            0.114
# KIC 9663113 b                 14.027                            0.137
# KOI-12 b                      11.510                            0.014
# KOI-1257 b                    14.818                            0.069
# KOI-13 b                       9.791                            0.023
# ...                              ...                              ...
# Kepler-997 b                  11.521                            0.038
# Kepler-998 b                  14.463                            0.080
# Kepler-999 b                  12.364                            0.069
# PH1 b                         13.841                            0.149
# PH2 b                         12.645                            0.046
#
#                V_(Johnson)_Magnitude_Lower_Unc  Ks_(2MASS)_Magnitude  \
# Planet_Name
# KIC 5437945 b                           -0.114                12.367
# KIC 9663113 b                           -0.137                12.502
# KOI-12 b                                -0.014                10.234
# KOI-1257 b                              -0.069                12.726
# KOI-13 b                                -0.023                 9.425
# ...                                        ...                   ...
# Kepler-997 b                            -0.038                10.608
# Kepler-998 b                            -0.080                12.888
# Kepler-999 b                            -0.069                10.916
# PH1 b                                   -0.149                12.395
# PH2 b                                   -0.046                11.116
#
#                Ks_(2MASS)_Magnitude_Upper_Unc  Ks_(2MASS)_Magnitude_Lower_Unc  \
# Planet_Name
# KIC 5437945 b                           0.027                          -0.027
# KIC 9663113 b                           0.023                          -0.023
# KOI-12 b                                0.018                          -0.018
# KOI-1257 b                              0.023                          -0.023
# KOI-13 b                                0.014                          -0.014
# ...                                       ...                             ...
# Kepler-997 b                            0.022                          -0.022
# Kepler-998 b                            0.031                          -0.031
# Kepler-999 b                            0.020                          -0.020
# PH1 b                                   0.021                          -0.021
# PH2 b                                   0.022                          -0.022
#
#                Gaia_Magnitude  Gaia_Magnitude_Upper_Unc  \
# Planet_Name
# KIC 5437945 b         13.7506                  0.000290
# KIC 9663113 b         13.9075                  0.000225
# KOI-12 b              11.2535                  0.000523
# KOI-1257 b            14.6419                  0.000490
# KOI-13 b              10.3678                  0.001225
# ...                       ...                       ...
# Kepler-997 b          11.8477                  0.000200
# Kepler-998 b          14.3408                  0.000233
# Kepler-999 b          12.2343                  0.000185
# PH1 b                 13.6988                  0.001604
# PH2 b                 12.5811                  0.000185
#
#                Gaia_Magnitude_Lower_Unc
# Planet_Name
# KIC 5437945 b                 -0.000290
# KIC 9663113 b                 -0.000225
# KOI-12 b                      -0.000523
# KOI-1257 b                    -0.000490
# KOI-13 b                      -0.001225
# ...                                 ...
# Kepler-997 b                  -0.000200
# Kepler-998 b                  -0.000233
# Kepler-999 b                  -0.000185
# PH1 b                         -0.001604
# PH2 b                         -0.000185
#
# [2666 rows x 83 columns]

# %%
#new_confirmed_planets_df = mergable_confirmed_planets_df.merge(new_planets_confirmed_df, left_index=True,right_index=True)
#new_confirmed_planets_df

# %%
new_confirmed_planets_df = mergable_confirmed_planets_df.merge(kepler_name_planets_df, left_index=True,right_index=True)
new_confirmed_planets_df
# Out:
#               Unnamed: 0   Host_Name  Number_of_Stars  Number_of_Planets  \
# Planet_Name
# Kepler-10 b         1650   Kepler-10                1                  2
# Kepler-10 c         1651   Kepler-10                1                  2
# Kepler-100 b        1652  Kepler-100                1                  3
# Kepler-100 c        1653  Kepler-100                1                  3
# Kepler-100 d        1654  Kepler-100                1                  3
# ...                  ...         ...              ...                ...
# Kepler-995 b        4322  Kepler-995                1                  1
# Kepler-996 b        4323  Kepler-996                1                  1
# Kepler-997 b        4324  Kepler-997                1                  1
# Kepler-998 b        4325  Kepler-998                1                  1
# Kepler-999 b        4326  Kepler-999                1                  1
#
#              Discovery_Method  Discovery_Year Discovery_Facility  \
# Planet_Name
# Kepler-10 b           Transit            2011             Kepler
# Kepler-10 c           Transit            2011             Kepler
# Kepler-100 b          Transit            2014             Kepler
# Kepler-100 c          Transit            2014             Kepler
# Kepler-100 d          Transit            2014             Kepler
# ...                       ...             ...                ...
# Kepler-995 b          Transit            2016             Kepler
# Kepler-996 b          Transit            2016             Kepler
# Kepler-997 b          Transit            2016             Kepler
# Kepler-998 b          Transit            2016             Kepler
# Kepler-999 b          Transit            2016             Kepler
#
#               Controversial_Flag  Orbital_Period_Upper_Unc._[days]_x  \
# Planet_Name
# Kepler-10 b                    0                            0.000002
# Kepler-10 c                    0                            0.000800
# Kepler-100 b                   0                                 NaN
# Kepler-100 c                   0                                 NaN
# Kepler-100 d                   0                                 NaN
# ...                          ...                                 ...
# Kepler-995 b                   0                            0.000086
# Kepler-996 b                   0                            0.000008
# Kepler-997 b                   0                            0.000006
# Kepler-998 b                   0                            0.000011
# Kepler-999 b                   0                            0.000008
#
#               Orbital_Period_Lower_Unc._[days]_x  ...  \
# Planet_Name                                       ...
# Kepler-10 b                            -0.000002  ...
# Kepler-10 c                            -0.000800  ...
# Kepler-100 b                                 NaN  ...
# Kepler-100 c                                 NaN  ...
# Kepler-100 d                                 NaN  ...
# ...                                          ...  ...
# Kepler-995 b                           -0.000086  ...
# Kepler-996 b                           -0.000008  ...
# Kepler-997 b                           -0.000006  ...
# Kepler-998 b                           -0.000011  ...
# Kepler-999 b                           -0.000008  ...
#
#               Stellar_Effective_Temperature_Lower_Unc._[K]_y  \
# Planet_Name
# Kepler-10 b                                            -68.0
# Kepler-10 c                                            -68.0
# Kepler-100 b                                           -78.0
# Kepler-100 c                                           -78.0
# Kepler-100 d                                           -78.0
# ...                                                      ...
# Kepler-995 b                                           -76.0
# Kepler-996 b                                           -77.0
# Kepler-997 b                                          -134.0
# Kepler-998 b                                          -179.0
# Kepler-999 b                                          -124.0
#
#               Stellar_Surface_Gravity_[log10(cm/s**2)]_y  \
# Planet_Name
# Kepler-10 b                                        4.347
# Kepler-10 c                                        4.347
# Kepler-100 b                                       4.122
# Kepler-100 c                                       4.122
# Kepler-100 d                                       4.122
# ...                                                  ...
# Kepler-995 b                                       4.457
# Kepler-996 b                                       4.274
# Kepler-997 b                                       4.069
# Kepler-998 b                                       4.507
# Kepler-999 b                                       4.049
#
#               Stellar_Surface_Gravity_Upper_Unc._[log10(cm/s**2)]_y  \
# Planet_Name
# Kepler-10 b                                               0.030
# Kepler-10 c                                               0.030
# Kepler-100 b                                              0.033
# Kepler-100 c                                              0.033
# Kepler-100 d                                              0.033
# ...                                                         ...
# Kepler-995 b                                              0.084
# Kepler-996 b                                              0.156
# Kepler-997 b                                              0.188
# Kepler-998 b                                              0.039
# Kepler-999 b                                              0.188
#
#               Stellar_Surface_Gravity_Lower_Unc._[log10(cm/s**2)]_y  \
# Planet_Name
# Kepler-10 b                                              -0.030
# Kepler-10 c                                              -0.030
# Kepler-100 b                                             -0.027
# Kepler-100 c                                             -0.027
# Kepler-100 d                                             -0.027
# ...                                                         ...
# Kepler-995 b                                             -0.039
# Kepler-996 b                                             -0.104
# Kepler-997 b                                             -0.101
# Kepler-998 b                                             -0.221
# Kepler-999 b                                             -0.101
#
#               Stellar_Radius_[Solar_radii]  \
# Planet_Name
# Kepler-10 b                          1.044
# Kepler-10 c                          1.044
# Kepler-100 b                         1.474
# Kepler-100 c                         1.474
# Kepler-100 d                         1.474
# ...                                    ...
# Kepler-995 b                         0.886
# Kepler-996 b                         1.208
# Kepler-997 b                         1.629
# Kepler-998 b                         0.934
# Kepler-999 b                         1.695
#
#               Stellar_Radius_Upper_Unc._[Solar_radii]  \
# Planet_Name
# Kepler-10 b                                     0.057
# Kepler-10 c                                     0.057
# Kepler-100 b                                    0.094
# Kepler-100 c                                    0.094
# Kepler-100 d                                    0.094
# ...                                               ...
# Kepler-995 b                                    0.049
# Kepler-996 b                                    0.193
# Kepler-997 b                                    0.281
# Kepler-998 b                                    0.294
# Kepler-999 b                                    0.300
#
#               Stellar_Radius_Lower_Unc._[Solar_radii]  RA_[decimal_degrees]  \
# Planet_Name
# Kepler-10 b                                    -0.042             285.67938
# Kepler-10 c                                    -0.042             285.67938
# Kepler-100 b                                   -0.079             291.38599
# Kepler-100 c                                   -0.079             291.38599
# Kepler-100 d                                   -0.079             291.38599
# ...                                               ...                   ...
# Kepler-995 b                                   -0.077             284.61572
# Kepler-996 b                                   -0.193             291.91281
# Kepler-997 b                                   -0.375             289.23337
# Kepler-998 b                                   -0.078             296.75415
# Kepler-999 b                                   -0.366             299.66046
#
#               Dec_[decimal_degrees]  Kepler-band_[mag]
# Planet_Name
# Kepler-10 b               50.241299             10.961
# Kepler-10 c               50.241299             10.961
# Kepler-100 b              41.990269             11.197
# Kepler-100 c              41.990269             11.197
# Kepler-100 d              41.990269             11.197
# ...                             ...                ...
# Kepler-995 b              39.131039             14.907
# Kepler-996 b              41.533611             14.668
# Kepler-997 b              49.938931             11.894
# Kepler-998 b              49.208740             14.377
# Kepler-999 b              46.198421             12.239
#
# [2620 rows x 131 columns]
